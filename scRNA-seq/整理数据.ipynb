# %% [markdown]
# ### author by yangshichen
# ### 注意：脚本仅供参考，使用前请仔细阅读

# %% [markdown]
# ### 加载包

# %%
import os
import glob
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
import seaborn as sb
import seaborn as sns
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt
from scipy.io import mmread
from scipy.sparse import csr_matrix
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import warnings
warnings.filterwarnings("ignore")

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=100, frameon=False)
sc._settings.ScanpyConfig.n_jobs=70
# Out:
# scanpy==1.9.3 anndata==0.8.0 numpy==1.21.6 scipy==1.7.3 pandas==1.3.5 scikit-learn==1.0.2 statsmodels==0.13.2 python-igraph==0.10.8 pynndescent==0.5.13

# %%
cluster_cols = ["#DC050C", "#FB8072", "#1965B0", "#7BAFDE", "#882E72", 
                "#B17BA6", "#FF7F00", "#FDB462", "#E7298A", "#E78AC3", 
                "#33A02C", "#B2DF8A", "#55A1B1", "#8DD3C7", "#A6761D", 
                "#E6AB02", "#7570B3", "#BEAED4", "#666666", "#999999", 
                "#aa8282", "#d4b7b7", "#8600bf", "#ba5ce3", "#808000", 
                "#aeae5c", "#1e90ff", "#00bfff", "#56ff0d", "#ffff00"]

# %% [markdown]
# ### 数据提取

# %%
adata = sc.read("/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/HIV-pbmc/pbmc_celltype.h5ad")
adata
# Out:
# AnnData object with n_obs × n_vars = 2744009 × 21679
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'doublet', 'batch', 'sample', 'stage', 'experiments', 'age', 'total_counts_rp', 'pct_counts_rp', 'total_counts_hb', 'pct_counts_hb', 'total_counts_ncRNA', 'pct_counts_ncRNA', 'total_counts_LOC', 'pct_counts_LOC', 'total_counts_erccs', 'pct_counts_erccs', 'celltype_L1', 'phase_ordered', 'celltype_L3', 'celltype_L1_5', 'celltype_L2'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'age_colors', 'celltype_L2_colors', 'experiments_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'phase_ordered_colors', 'stage_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
subdata = adata[adata.obs['celltype_L3'].isin(['CD4_Naive_T-CCR7','CD4_Tcm-IFIT3','CD4_Th1-GZMK','CD4_Treg-FOXP3',
                                               'CD8_CTL-GZMB','NKT-NCR1',
                                               'NK_bright-XCL1','Mature_NK_dim-FCGR3A',
                                               'cMono-CD14','ncMono-FCGR3A','cDC2-CD1C',
                                               'Aptypical_Memory_B-ITGAX'])]
subdata = subdata[subdata.obs['stage'].isin(['INRs'])]
subdata
# Out:
# View of AnnData object with n_obs × n_vars = 376099 × 21679
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'doublet_score', 'doublet', 'batch', 'sample', 'stage', 'experiments', 'age', 'total_counts_rp', 'pct_counts_rp', 'total_counts_hb', 'pct_counts_hb', 'total_counts_ncRNA', 'pct_counts_ncRNA', 'total_counts_LOC', 'pct_counts_LOC', 'total_counts_erccs', 'pct_counts_erccs', 'celltype_L1', 'phase_ordered', 'celltype_L3', 'celltype_L1_5', 'celltype_L2'
#     var: 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'highly_variable_nbatches', 'highly_variable_intersection', 'mean', 'std'
#     uns: 'age_colors', 'celltype_L2_colors', 'experiments_colors', 'hvg', 'log1p', 'neighbors', 'pca', 'phase_ordered_colors', 'stage_colors', 'umap'
#     obsm: 'X_pca', 'X_pca_harmony', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
subdata.obs['celltype_L3'].value_counts()
# Out:
# CD8_CTL-GZMB                110373
# NKT-NCR1                     83973
# cMono-CD14                   72616
# Mature_NK_dim-FCGR3A         40455
# CD4_Naive_T-CCR7             21297
# ncMono-FCGR3A                18599
# NK_bright-XCL1                7123
# cDC2-CD1C                     5832
# CD4_Treg-FOXP3                5385
# CD4_Th1-GZMK                  5335
# CD4_Tcm-IFIT3                 2652
# Aptypical_Memory_B-ITGAX      2459
# Name: celltype_L3, dtype: int64

# %%
del adata

# %% [markdown]
# #### 基因

# %%
genes = ['NFKBIA','TNFAIP3','STAT1','DUSP1','XAF1','IFI44L','ISG15','MX1','OAS1','S100A9','CXCL8','IFITM3','IL1B','NR4A2','IFI30']

# %%
adata_sub = subdata[:, genes]

mean_expr = (
    adata_sub.to_df()
    .groupby([adata_sub.obs["sample"], adata_sub.obs["celltype_L3"]])
    .mean()
)
mean_expr
# Out:
# gene_id                             NFKBIA   TNFAIP3     STAT1     DUSP1  \
# sample  celltype_L3
# PD-H201 Aptypical_Memory_B-ITGAX  0.833531 -0.254777 -0.156377  0.901096
#         CD4_Naive_T-CCR7          0.371418  0.956498  0.231434  0.174950
#         CD4_Tcm-IFIT3             0.740856  1.434940  1.010490  0.968417
#         CD4_Th1-GZMK              1.045024  1.680073  0.677775  1.213249
#         CD4_Treg-FOXP3            0.290329  0.953683  0.677762  1.134511
# ...                                    ...       ...       ...       ...
# PD-H289 NKT-NCR1                 -0.667271 -0.614711 -0.019175 -0.811548
#         NK_bright-XCL1           -0.125728 -0.426851  0.210231 -0.212733
#         cDC2-CD1C                -0.304221 -0.702310 -0.060165 -0.368599
#         cMono-CD14               -0.305764 -0.688962 -0.016234 -0.617008
#         ncMono-FCGR3A            -0.553721 -0.778654 -0.070773  0.092304
#
# gene_id                               XAF1    IFI44L     ISG15       MX1  \
# sample  celltype_L3
# PD-H201 Aptypical_Memory_B-ITGAX -0.024188  0.201257 -0.078881  0.478866
#         CD4_Naive_T-CCR7          0.150244  0.236106  0.038843  0.111567
#         CD4_Tcm-IFIT3             0.664179  1.178573  1.435343  1.657381
#         CD4_Th1-GZMK              0.213342  0.498589  0.210928  0.033209
#         CD4_Treg-FOXP3            0.235060  0.106439  0.295296  0.439322
# ...                                    ...       ...       ...       ...
# PD-H289 NKT-NCR1                  0.254476 -0.198231 -0.000727 -0.030709
#         NK_bright-XCL1            0.411970  0.004112  0.054498 -0.050173
#         cDC2-CD1C                 0.723503  0.004958 -0.030369  0.137471
#         cMono-CD14                1.041899  0.135306 -0.046583  0.203666
#         ncMono-FCGR3A             0.451310 -0.054141  0.302311  0.295957
#
# gene_id                               OAS1    S100A9     CXCL8    IFITM3  \
# sample  celltype_L3
# PD-H201 Aptypical_Memory_B-ITGAX  0.393136 -0.149591 -0.156967 -0.264516
#         CD4_Naive_T-CCR7         -0.094873 -0.188185 -0.136781 -0.080016
#         CD4_Tcm-IFIT3             0.876014 -0.054307 -0.156967  0.307510
#         CD4_Th1-GZMK             -0.082039 -0.226257 -0.156967 -0.098016
#         CD4_Treg-FOXP3            0.979216 -0.321683 -0.156967 -0.108249
# ...                                    ...       ...       ...       ...
# PD-H289 NKT-NCR1                  0.100455 -0.452246 -0.156967  0.000772
#         NK_bright-XCL1            0.014685 -0.472834 -0.156967  0.936535
#         cDC2-CD1C                 0.058768  0.877298 -0.115080 -0.032227
#         cMono-CD14               -0.089750  2.164000 -0.099774 -0.176570
#         ncMono-FCGR3A             1.474611  0.413298 -0.039390  1.509133
#
# gene_id                               IL1B     NR4A2     IFI30
# sample  celltype_L3
# PD-H201 Aptypical_Memory_B-ITGAX -0.097062  2.312644  0.743929
#         CD4_Naive_T-CCR7         -0.132017  0.515810 -0.323075
#         CD4_Tcm-IFIT3            -0.170849  1.145844 -0.220889
#         CD4_Th1-GZMK             -0.041544  1.572081 -0.307724
#         CD4_Treg-FOXP3           -0.036958  0.783501 -0.312960
# ...                                    ...       ...       ...
# PD-H289 NKT-NCR1                 -0.170849 -0.436992 -0.251638
#         NK_bright-XCL1           -0.170849 -0.442006 -0.360221
#         cDC2-CD1C                 0.344117 -0.065096  1.492741
#         cMono-CD14                0.094182 -0.256069  0.348524
#         ncMono-FCGR3A            -0.010463 -0.376096  2.556771
#
# [516 rows x 15 columns]

# %%
mean_expr.to_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/genescore.csv', index=True)

# %% [markdown]
# #### 通路

# %%
gene_sets = {} 
folder_path = '/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/pathway/'
txt_files = glob.glob(os.path.join(folder_path, '*.txt'))
for file_path in txt_files:
    with open(file_path, 'r') as file:
        gene_set_name = file.readline().strip()
        gene_list = []
        for line in file:
            gene = line.strip()
            gene_list.append(gene)
        gene_sets[gene_set_name] = gene_list

# %%
for gene_set_name, gene_list in gene_sets.items():
    sc.tl.score_genes(subdata, gene_list, score_name=gene_set_name)
# Out:
# computing score 'GOBP_INFLAMMATORY_RESPONSE'
# WARNING: genes are not in var_names and ignored: ['MIR675', 'MIR920', 'MIR302E', 'MIR4286', 'MIR3909', 'MIR6869', 'PYDC5', 'TREX1', 'H2BC1', 'GBA1', 'GGT3P', 'GPR32P1', 'GPX1', 'STING1', 'KARS1', '', 'MIRLET7G', 'MIR105-1', 'MIR125A', 'MIR126', 'MIR128-1', 'MIR129-1', 'MIR130B', 'MIR135A1', 'MIR136', 'MIR138-1', 'MIR140', 'MIR141', 'MIR142', 'MIR144', 'MIR145', 'MIR146A', 'MIR149', 'MIR15A', 'MIR15B', 'MIR16-1', 'MIR17', 'MIR181A2', 'MIR181B1', 'MIR181C', 'MIR187', 'MIR195', 'MIR197', 'MIR199A1', 'MIR19A', 'MIR19B1', 'MIR20A', 'MIR203A', 'MIR204', 'MIR205', 'MIR206', 'MIR21', 'MIR22', 'MIR221', 'MIR222', 'MIR223', 'MIR26A1', 'MIR30C2', 'MIR31', 'MIR92A1', 'MIR93', 'MIR98', 'CCL3L3', 'MIR324', 'MIR338', 'MIR361', 'MIR378A', 'MIR488', 'RPS19', 'MIR590', 'MIR657', 'GGT2P', 'MIR766', 'RPS6KA4', 'MACIR', 'RPS6KA5']
#     finished: added
#     'GOBP_INFLAMMATORY_RESPONSE', score of gene set (adata.obs).
#     1157 total control genes are used. (0:15:51)
# computing score 'HALLMARK_APOPTOSIS'
# WARNING: genes are not in var_names and ignored: ['GPX1', 'LPPR4', 'SC5DL']
#     finished: added
#     'HALLMARK_APOPTOSIS', score of gene set (adata.obs).
#     1096 total control genes are used. (0:00:28)
# computing score 'HALLMARK_INTERFERON_GAMMA_RESPONSE'
# WARNING: genes are not in var_names and ignored: ['FTSJD2', 'PRIC285']
#     finished: added
#     'HALLMARK_INTERFERON_GAMMA_RESPONSE', score of gene set (adata.obs).
#     995 total control genes are used. (0:00:40)
# computing score 'HALLMARK_TNFA_SIGNALING_VIA_NFKB'
# WARNING: genes are not in var_names and ignored: ['CXCR7', 'CYR61', 'HBEGF', 'PPAP2B']
#     finished: added
#     'HALLMARK_TNFA_SIGNALING_VIA_NFKB', score of gene set (adata.obs).
#     1039 total control genes are used. (0:00:08)
# computing score 'Module_Activation'
#     finished: added
#     'Module_Activation', score of gene set (adata.obs).
#     349 total control genes are used. (0:00:07)

# %%
gene_set_names = gene_sets.keys()
gene_set_names = [str(name) for name in gene_set_names]
gene_set_names
# Out:
# ['GOBP_INFLAMMATORY_RESPONSE',
#  'HALLMARK_APOPTOSIS',
#  'HALLMARK_INTERFERON_GAMMA_RESPONSE',
#  'HALLMARK_TNFA_SIGNALING_VIA_NFKB',
#  'Module_Activation']

# %%
gene_set_df = subdata.obs[["sample","celltype_L3"]+ gene_set_names]
gene_set_df
# Out:
#                          sample               celltype_L3  \
# cellbarcode
# PD-H214-1-CELL98_N1     PD-H214  Aptypical_Memory_B-ITGAX
# PD-H214-1-CELL226_N2    PD-H214  Aptypical_Memory_B-ITGAX
# PD-H214-1-CELL241_N2    PD-H214  Aptypical_Memory_B-ITGAX
# PD-H214-1-CELL328_N2    PD-H214  Aptypical_Memory_B-ITGAX
# PD-H214-1-CELL509_N4    PD-H214  Aptypical_Memory_B-ITGAX
# ...                         ...                       ...
# PD-H264-2-CELL10487_N1  PD-H264      Mature_NK_dim-FCGR3A
# PD-H264-2-CELL11345_N1  PD-H264      Mature_NK_dim-FCGR3A
# PD-H265-1-CELL1521_N2   PD-H265      Mature_NK_dim-FCGR3A
# PD-H265-1-CELL4348_N1   PD-H265      Mature_NK_dim-FCGR3A
# PD-H266-1-CELL8814_N1   PD-H266      Mature_NK_dim-FCGR3A
#
#                         GOBP_INFLAMMATORY_RESPONSE  HALLMARK_APOPTOSIS  \
# cellbarcode
# PD-H214-1-CELL98_N1                       0.049152            0.266420
# PD-H214-1-CELL226_N2                     -0.037740            0.095684
# PD-H214-1-CELL241_N2                      0.061577            0.261756
# PD-H214-1-CELL328_N2                      0.039787            0.149042
# PD-H214-1-CELL509_N4                     -0.016201            0.226748
# ...                                            ...                 ...
# PD-H264-2-CELL10487_N1                    0.102440            0.122817
# PD-H264-2-CELL11345_N1                    0.051894            0.210756
# PD-H265-1-CELL1521_N2                     0.073243            0.110803
# PD-H265-1-CELL4348_N1                     0.041072            0.302505
# PD-H266-1-CELL8814_N1                     0.024421            0.247857
#
#                         HALLMARK_INTERFERON_GAMMA_RESPONSE  \
# cellbarcode
# PD-H214-1-CELL98_N1                               0.449499
# PD-H214-1-CELL226_N2                              0.308991
# PD-H214-1-CELL241_N2                              0.399363
# PD-H214-1-CELL328_N2                              0.434981
# PD-H214-1-CELL509_N4                              0.494304
# ...                                                    ...
# PD-H264-2-CELL10487_N1                            0.303869
# PD-H264-2-CELL11345_N1                            0.463105
# PD-H265-1-CELL1521_N2                             0.389919
# PD-H265-1-CELL4348_N1                             0.398605
# PD-H266-1-CELL8814_N1                             0.351094
#
#                         HALLMARK_TNFA_SIGNALING_VIA_NFKB  Module_Activation
# cellbarcode
# PD-H214-1-CELL98_N1                             0.245041           1.123951
# PD-H214-1-CELL226_N2                            0.390797           1.189758
# PD-H214-1-CELL241_N2                            0.256501           1.614679
# PD-H214-1-CELL328_N2                            0.558054           1.012030
# PD-H214-1-CELL509_N4                            0.503742           1.610318
# ...                                                  ...                ...
# PD-H264-2-CELL10487_N1                          0.032498           0.002844
# PD-H264-2-CELL11345_N1                          0.200207           0.015804
# PD-H265-1-CELL1521_N2                          -0.040620          -0.041338
# PD-H265-1-CELL4348_N1                           0.130260          -0.186057
# PD-H266-1-CELL8814_N1                           0.175467          -0.197555
#
# [376099 rows x 7 columns]

# %%
mean_expr = gene_set_df.groupby(['sample', 'celltype_L3']).mean(numeric_only=True).reset_index()
mean_expr
# Out:
#       sample               celltype_L3  GOBP_INFLAMMATORY_RESPONSE  \
# 0    PD-H201  Aptypical_Memory_B-ITGAX                    0.020751
# 1    PD-H201          CD4_Naive_T-CCR7                   -0.009544
# 2    PD-H201             CD4_Tcm-IFIT3                    0.051373
# 3    PD-H201              CD4_Th1-GZMK                    0.025986
# 4    PD-H201            CD4_Treg-FOXP3                    0.014794
# ..       ...                       ...                         ...
# 511  PD-H289                  NKT-NCR1                    0.028425
# 512  PD-H289            NK_bright-XCL1                    0.050324
# 513  PD-H289                 cDC2-CD1C                    0.114515
# 514  PD-H289                cMono-CD14                    0.091816
# 515  PD-H289             ncMono-FCGR3A                    0.147196
#
#      HALLMARK_APOPTOSIS  HALLMARK_INTERFERON_GAMMA_RESPONSE  \
# 0              0.193867                            0.400405
# 1              0.162159                            0.258957
# 2              0.274987                            0.506853
# 3              0.273874                            0.397487
# 4              0.250748                            0.360237
# ..                  ...                                 ...
# 511            0.164808                            0.339574
# 512            0.161488                            0.370088
# 513            0.222115                            0.358233
# 514            0.174365                            0.304365
# 515            0.264030                            0.441628
#
#      HALLMARK_TNFA_SIGNALING_VIA_NFKB  Module_Activation
# 0                            0.415400           1.414027
# 1                            0.196262          -0.096521
# 2                            0.304682           0.027822
# 3                            0.382809           0.285075
# 4                            0.289095           1.090625
# ..                                ...                ...
# 511                          0.056561           0.063441
# 512                          0.073563          -0.057590
# 513                          0.135326           0.902650
# 514                          0.157479           0.127865
# 515                          0.236945           0.150434
#
# [516 rows x 7 columns]

# %%
mean_expr.to_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/pathwayscore.csv', index=False)

# %% [markdown]
# #### RNA细胞比例

# %%
tmp = pd.read_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/scRNA_proportions_L3.csv')
tmp
# Out:
#        sample               celltype_L3  count  total_count  proportion
# 0     HD-H134  Aptypical_Memory_B-ITGAX     76        46020    0.001651
# 1     HD-H134          CD4_Naive_T-CCR7   7030        46020    0.152760
# 2     HD-H134          CD4_Naive_T-SOX4    604        46020    0.013125
# 3     HD-H134             CD4_Tcm-CXCR5   1071        46020    0.023272
# 4     HD-H134            CD4_Tcm-GPR183    719        46020    0.015624
# ...       ...                       ...    ...          ...         ...
# 8231  PD-H308             ncMono-FCGR3A    260        10767    0.024148
# 8232  PD-H308             ncMono-IFI44L    110        10767    0.010216
# 8233  PD-H308              ncMono-IFIT1     30        10767    0.002786
# 8234  PD-H308                   pDC-AXL      1        10767    0.000093
# 8235  PD-H308                pDC-LILRA4     71        10767    0.006594
#
# [8236 rows x 5 columns]

# %%
subtmp = tmp[tmp['celltype_L3'].isin(['CD4_Naive_T-CCR7','CD4_Tcm-IFIT3','CD4_Th1-GZMK','CD4_Treg-FOXP3',
                                      'CD8_CTL-GZMB','NKT-NCR1','NK_bright-XCL1','Mature_NK_dim-FCGR3A',
                                      'cMono-CD14','ncMono-FCGR3A','cDC2-CD1C','Aptypical_Memory_B-ITGAX'])]
subtmp = subtmp[subtmp['sample'].isin(['PD-H201','PD-H202','PD-H204','PD-H207','PD-H210','PD-H212','PD-H214','PD-H218','PD-H219','PD-H220','PD-H221','PD-H222',
                                       'PD-H223','PD-H224','PD-H225','PD-H228','PD-H229','PD-H230','PD-H231','PD-H232','PD-H233','PD-H237','PD-H238','PD-H240',
                                       'PD-H241','PD-H242','PD-H246','PD-H247','PD-H255','PD-H258','PD-H260','PD-H263','PD-H264','PD-H265','PD-H266','PD-H276',
                                       'PD-H277','PD-H278','PD-H281','PD-H285','PD-H286','PD-H288','PD-H289'])]
subtmp
# Out:
#        sample               celltype_L3  count  total_count  proportion
# 3074  PD-H201  Aptypical_Memory_B-ITGAX     36        15587    0.002310
# 3075  PD-H201          CD4_Naive_T-CCR7    378        15587    0.024251
# 3079  PD-H201             CD4_Tcm-IFIT3     16        15587    0.001026
# 3083  PD-H201              CD4_Th1-GZMK     40        15587    0.002566
# 3088  PD-H201            CD4_Treg-FOXP3     51        15587    0.003272
# ...       ...                       ...    ...          ...         ...
# 7451  PD-H289                  NKT-NCR1    730        16623    0.043915
# 7452  PD-H289            NK_bright-XCL1     85        16623    0.005113
# 7469  PD-H289                 cDC2-CD1C    122        16623    0.007339
# 7470  PD-H289                cMono-CD14   1127        16623    0.067798
# 7477  PD-H289             ncMono-FCGR3A    531        16623    0.031944
#
# [516 rows x 5 columns]

# %%
subtmp.to_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/rnacellratio.csv', index=False)

# %% [markdown]
# #### 临床细胞数：CD4、CD4/CD8

# %%
tmp = pd.read_excel('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/sample_information.xlsx')
tmp
# Out:
#       Sample Group Gender  Age Treat time Baseline viral load (cp/mL)  \
# 0    HD-H134   HDs      M   53         ——                          ——
# 1    HD-H135   HDs      M   26         ——                          ——
# 2    HD-H136   HDs      M   28         ——                          ——
# 3    HD-H137   HDs      M   31         ——                          ——
# 4    HD-H138   HDs      M   32         ——                          ——
# ..       ...   ...    ...  ...        ...                         ...
# 138  PD-H302   IRs      M   37          5                        6690
# 139  PD-H305   IRs      M   36          5                        4445
# 140  PD-H306   IRs      M   31          5                           0
# 141  PD-H307   IRs      M   60          6                       86100
# 142  PD-H308   IRs      M   50          8                       18400
#
#     Viral load (cp/mL) Baseline CD4 count (/μL) CD4 count (/μL)  \
# 0                   ——                       ——             579
# 1                   ——                       ——             595
# 2                   ——                       ——            1035
# 3                   ——                       ——             852
# 4                   ——                       ——             667
# ..                 ...                      ...             ...
# 138                  0                        7             800
# 139                  0                      533             728
# 140                  0                      386             502
# 141                  0                      270             542
# 142                  0                        7             572
#
#     CD8 count(/μL) CD4/CD8 Ratio  ART regimen INSTI
# 0              319      1.815047           ——    ——
# 1              754      0.789125           ——    ——
# 2              428      2.418224           ——    ——
# 3              779       1.09371           ——    ——
# 4             1040      0.641346           ——    ——
# ..             ...           ...          ...   ...
# 138           2148      0.372439  AZT/3TC+EFV    No
# 139            507      1.435897  3TC+EFV+TDF    No
# 140            491      1.022403  BIC/FTC/TAF   Yes
# 141            286      1.895105  BIC/FTC/TAF   Yes
# 142            584      0.979452  3TC+EFV+TDF    No
#
# [143 rows x 13 columns]

# %%
subtmp = tmp[tmp['Group'].isin(['INRs'])]
subtmp
# Out:
#       Sample Group Gender  Age Treat time Baseline viral load (cp/mL)  \
# 53   PD-H201  INRs      M   38          5                       97000
# 54   PD-H202  INRs      M   76          6                           0
# 56   PD-H204  INRs      M   55         13                           0
# 58   PD-H207  INRs      M   61          9                         250
# 61   PD-H210  INRs      M   36         10                          20
# 63   PD-H212  INRs      M   46          4                           0
# 65   PD-H214  INRs      M   41          9                           0
# 67   PD-H218  INRs      M   70          9                           0
# 68   PD-H219  INRs      M   37          7                           0
# 69   PD-H220  INRs      M   60          5                           0
# 70   PD-H221  INRs      M   59          5                           0
# 71   PD-H222  INRs      M   55          9                           0
# 72   PD-H223  INRs      M   65          5                           0
# 73   PD-H224  INRs      M   61         13                           0
# 74   PD-H225  INRs      M   61          7                        7220
# 77   PD-H228  INRs      M   28          5                           0
# 78   PD-H229  INRs      M   55          7                       28600
# 79   PD-H230  INRs      M   47          5                        1700
# 80   PD-H231  INRs      M   42          9                           0
# 81   PD-H232  INRs      M   47          5                        3920
# 82   PD-H233  INRs      M   41          8                         338
# 86   PD-H237  INRs      M   33          9                        1900
# 87   PD-H238  INRs      M   67          7                       11800
# 89   PD-H240  INRs      M   36          8                           0
# 90   PD-H241  INRs      M   43          9                         112
# 91   PD-H242  INRs      M   72         10                           0
# 94   PD-H246  INRs      M   40          5                        4500
# 95   PD-H247  INRs      M   35          7                         149
# 102  PD-H255  INRs      M   71         10                           0
# 103  PD-H258  INRs      M   36          7                        55.4
# 104  PD-H260  INRs      M   50         10                           0
# 106  PD-H263  INRs      M   31          5                       10511
# 107  PD-H264  INRs      M   38          7                        1180
# 108  PD-H265  INRs      M   39          9                           0
# 109  PD-H266  INRs      M   43          5                         545
# 118  PD-H276  INRs      M   61          4                       13400
# 119  PD-H277  INRs      M   55          9                           0
# 120  PD-H278  INRs      M   52          6                           0
# 122  PD-H281  INRs      M   37          6                        2980
# 125  PD-H285  INRs      M   39          5                     3315000
# 126  PD-H286  INRs      M   57         10                           0
# 128  PD-H288  INRs      M   33          5                           0
# 129  PD-H289  INRs      M   34          5                           0
#
#     Viral load (cp/mL) Baseline CD4 count (/μL) CD4 count (/μL)  \
# 53                25.1                       34             206
# 54                   0                       56             128
# 56                   0                      122             252
# 58                   0                        1             269
# 61                   0                       56             240
# 63                   0                       32             151
# 65                   0                      182             282
# 67                   0                       29             175
# 68                   0                       13             208
# 69                   0                       12             124
# 70                23.2                       36             156
# 71                   0                      102             129
# 72                   0                       34             108
# 73                   0                      209             262
# 74                   0                       16             257
# 77                   0                      100             261
# 78                   0                      106             161
# 79                   0                        4             200
# 80                   0                      112             199
# 81                   0                       93             175
# 82                   0                       15             239
# 86                   0                      145             241
# 87                   0                       60             101
# 89                   0                       47             260
# 90                   0                      240             131
# 91                   0                       72             229
# 94                   0                       43             240
# 95                   0                       49             240
# 102                  0                       18             211
# 103                  0                       29             235
# 104                  0                      150             210
# 106                  0                      139             249
# 107                  0                      279             132
# 108                  0                       13             174
# 109                  0                       41             229
# 118                  0                       22             196
# 119                  0                      100             245
# 120                  0                       52             148
# 122                  0                        9             258
# 125                  0                       22             263
# 126                  0                       19             206
# 128                  0                      134             236
# 129                  0                       32             229
#
#     CD8 count(/μL) CD4/CD8 Ratio    ART regimen INSTI
# 53             700      0.294286    BIC/FTC/TAF   Yes
# 54             338      0.378698    3TC+EFV+TDF    No
# 56             652      0.386503    AZT/3TC+NVP    No
# 58             512      0.525391    3TC+EFV+TDF    No
# 61            1010      0.237624    BIC/FTC/TAF   Yes
# 63             569      0.265378    3TC+EFV+TDF    No
# 65             552       0.51087    BIC/FTC/TAF   Yes
# 67             320      0.546875    3TC+EFV+TDF    No
# 68             881      0.236095    BIC/FTC/TAF   Yes
# 69             374      0.331551    BIC/FTC/TAF   Yes
# 70             355      0.439437    BIC/FTC/TAF   Yes
# 71             280      0.460714    3TC+EFV+TDF    No
# 72             451      0.239468  EVG/c/FTC/TAF   Yes
# 73             594      0.441077    AZT/3TC+NVP    No
# 74             393      0.653944    BIC/FTC/TAF   Yes
# 77             659      0.396055    BIC/FTC/TAF   Yes
# 78            1060      0.151887    BIC/FTC/TAF   Yes
# 79             747      0.267738    BIC/FTC/TAF   Yes
# 80             193      1.031088    3TC+EFV+TDF    No
# 81             810      0.216049    BIC/FTC/TAF   Yes
# 82             643      0.371695    BIC/FTC/TAF   Yes
# 86             337      0.715134    BIC/FTC/TAF   Yes
# 87             374      0.270053    AZT/3TC+NVP    No
# 89             474      0.548523    3TC+EFV+TDF    No
# 90             686      0.190962      3TC+LPV/r    No
# 91             321      0.713396    AZT/3TC+NVP    No
# 94             774      0.310078    3TC+EFV+TDF    No
# 95             667       0.35982    BIC/FTC/TAF   Yes
# 102            177       1.19209    3TC+EFV+TDF    No
# 103            605       0.38843    BIC/FTC/TAF   Yes
# 104            385      0.545455    AZT/3TC+EFV    No
# 106            623      0.399679  EVG/c/FTC/TAF   Yes
# 107            664      0.198795        3TC/DTG   Yes
# 108            586      0.296928    BIC/FTC/TAF   Yes
# 109            445      0.514607    BIC/FTC/TAF   Yes
# 118            433      0.452656    BIC/FTC/TAF   Yes
# 119            476      0.514706    AZT/3TC+EFV    No
# 120            413      0.358354    AZT/3TC+EFV    No
# 122            862      0.299304    3TC+EFV+TDF    No
# 125            816      0.322304    3TC+EFV+TDF    No
# 126            551      0.373866    AZT/3TC+EFV    No
# 128            371      0.636119        3TC/DTG   Yes
# 129            823       0.27825    BIC/FTC/TAF   Yes

# %%
subtmp.to_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/clinicalinformation.csv', index=False)

# %% [markdown]
# ### 计算相关性和差异

# %% [markdown]
# #### 数据合并

# %%
tmp1 = pd.read_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/genescore.csv')
tmp1
# Out:
#       sample               celltype_L3    NFKBIA   TNFAIP3     STAT1  \
# 0    PD-H201  Aptypical_Memory_B-ITGAX  0.833531 -0.254777 -0.156377
# 1    PD-H201          CD4_Naive_T-CCR7  0.371418  0.956498  0.231434
# 2    PD-H201             CD4_Tcm-IFIT3  0.740856  1.434940  1.010490
# 3    PD-H201              CD4_Th1-GZMK  1.045024  1.680073  0.677775
# 4    PD-H201            CD4_Treg-FOXP3  0.290329  0.953683  0.677762
# ..       ...                       ...       ...       ...       ...
# 511  PD-H289                  NKT-NCR1 -0.667271 -0.614711 -0.019175
# 512  PD-H289            NK_bright-XCL1 -0.125728 -0.426851  0.210231
# 513  PD-H289                 cDC2-CD1C -0.304221 -0.702310 -0.060165
# 514  PD-H289                cMono-CD14 -0.305764 -0.688962 -0.016234
# 515  PD-H289             ncMono-FCGR3A -0.553721 -0.778654 -0.070773
#
#         DUSP1      XAF1    IFI44L     ISG15       MX1      OAS1    S100A9  \
# 0    0.901096 -0.024188  0.201257 -0.078881  0.478866  0.393136 -0.149591
# 1    0.174950  0.150244  0.236106  0.038843  0.111567 -0.094873 -0.188185
# 2    0.968417  0.664179  1.178573  1.435343  1.657381  0.876014 -0.054307
# 3    1.213249  0.213342  0.498589  0.210928  0.033209 -0.082039 -0.226257
# 4    1.134511  0.235060  0.106439  0.295296  0.439322  0.979216 -0.321683
# ..        ...       ...       ...       ...       ...       ...       ...
# 511 -0.811547  0.254476 -0.198231 -0.000727 -0.030709  0.100455 -0.452246
# 512 -0.212733  0.411970  0.004112  0.054498 -0.050173  0.014685 -0.472834
# 513 -0.368599  0.723503  0.004958 -0.030369  0.137471  0.058768  0.877298
# 514 -0.617008  1.041899  0.135306 -0.046583  0.203666 -0.089750  2.164000
# 515  0.092304  0.451310 -0.054141  0.302311  0.295957  1.474611  0.413298
#
#         CXCL8    IFITM3      IL1B     NR4A2     IFI30
# 0   -0.156967 -0.264516 -0.097062  2.312644  0.743929
# 1   -0.136781 -0.080016 -0.132017  0.515810 -0.323075
# 2   -0.156967  0.307510 -0.170849  1.145844 -0.220889
# 3   -0.156967 -0.098016 -0.041544  1.572081 -0.307724
# 4   -0.156967 -0.108249 -0.036958  0.783501 -0.312960
# ..        ...       ...       ...       ...       ...
# 511 -0.156967  0.000772 -0.170849 -0.436992 -0.251638
# 512 -0.156967  0.936535 -0.170849 -0.442006 -0.360221
# 513 -0.115080 -0.032227  0.344117 -0.065096  1.492741
# 514 -0.099774 -0.176570  0.094182 -0.256069  0.348524
# 515 -0.039390  1.509133 -0.010463 -0.376096  2.556771
#
# [516 rows x 17 columns]

# %%
tmp2 = pd.read_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/pathwayscore.csv')
tmp2
# Out:
#       sample               celltype_L3  GOBP_INFLAMMATORY_RESPONSE  \
# 0    PD-H201  Aptypical_Memory_B-ITGAX                    0.020751
# 1    PD-H201          CD4_Naive_T-CCR7                   -0.009544
# 2    PD-H201             CD4_Tcm-IFIT3                    0.051373
# 3    PD-H201              CD4_Th1-GZMK                    0.025986
# 4    PD-H201            CD4_Treg-FOXP3                    0.014794
# ..       ...                       ...                         ...
# 511  PD-H289                  NKT-NCR1                    0.028425
# 512  PD-H289            NK_bright-XCL1                    0.050324
# 513  PD-H289                 cDC2-CD1C                    0.114515
# 514  PD-H289                cMono-CD14                    0.091816
# 515  PD-H289             ncMono-FCGR3A                    0.147196
#
#      HALLMARK_APOPTOSIS  HALLMARK_INTERFERON_GAMMA_RESPONSE  \
# 0              0.193867                            0.400405
# 1              0.162159                            0.258957
# 2              0.274987                            0.506853
# 3              0.273874                            0.397487
# 4              0.250748                            0.360237
# ..                  ...                                 ...
# 511            0.164808                            0.339574
# 512            0.161488                            0.370088
# 513            0.222115                            0.358233
# 514            0.174365                            0.304365
# 515            0.264030                            0.441628
#
#      HALLMARK_TNFA_SIGNALING_VIA_NFKB  Module_Activation
# 0                            0.415400           1.414027
# 1                            0.196262          -0.096521
# 2                            0.304682           0.027822
# 3                            0.382809           0.285075
# 4                            0.289095           1.090625
# ..                                ...                ...
# 511                          0.056561           0.063441
# 512                          0.073563          -0.057590
# 513                          0.135326           0.902650
# 514                          0.157479           0.127865
# 515                          0.236945           0.150434
#
# [516 rows x 7 columns]

# %%
tmp3 = pd.read_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/rnacellratio.csv')
tmp3
# Out:
#       sample               celltype_L3  count  total_count  proportion
# 0    PD-H201  Aptypical_Memory_B-ITGAX     36        15587    0.002310
# 1    PD-H201          CD4_Naive_T-CCR7    378        15587    0.024251
# 2    PD-H201             CD4_Tcm-IFIT3     16        15587    0.001026
# 3    PD-H201              CD4_Th1-GZMK     40        15587    0.002566
# 4    PD-H201            CD4_Treg-FOXP3     51        15587    0.003272
# ..       ...                       ...    ...          ...         ...
# 511  PD-H289                  NKT-NCR1    730        16623    0.043915
# 512  PD-H289            NK_bright-XCL1     85        16623    0.005113
# 513  PD-H289                 cDC2-CD1C    122        16623    0.007339
# 514  PD-H289                cMono-CD14   1127        16623    0.067798
# 515  PD-H289             ncMono-FCGR3A    531        16623    0.031944
#
# [516 rows x 5 columns]

# %%
tmp4 = pd.read_csv('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/INRs/数据/clinicalinformation.csv')
colnames(
tmp4
# Out:
#      Sample Group Gender  Age  Treat time  Baseline viral load (cp/mL)  \
# 0   PD-H201  INRs      M   38           5                      97000.0
# 1   PD-H202  INRs      M   76           6                          0.0
# 2   PD-H204  INRs      M   55          13                          0.0
# 3   PD-H207  INRs      M   61           9                        250.0
# 4   PD-H210  INRs      M   36          10                         20.0
# 5   PD-H212  INRs      M   46           4                          0.0
# 6   PD-H214  INRs      M   41           9                          0.0
# 7   PD-H218  INRs      M   70           9                          0.0
# 8   PD-H219  INRs      M   37           7                          0.0
# 9   PD-H220  INRs      M   60           5                          0.0
# 10  PD-H221  INRs      M   59           5                          0.0
# 11  PD-H222  INRs      M   55           9                          0.0
# 12  PD-H223  INRs      M   65           5                          0.0
# 13  PD-H224  INRs      M   61          13                          0.0
# 14  PD-H225  INRs      M   61           7                       7220.0
# 15  PD-H228  INRs      M   28           5                          0.0
# 16  PD-H229  INRs      M   55           7                      28600.0
# 17  PD-H230  INRs      M   47           5                       1700.0
# 18  PD-H231  INRs      M   42           9                          0.0
# 19  PD-H232  INRs      M   47           5                       3920.0
# 20  PD-H233  INRs      M   41           8                        338.0
# 21  PD-H237  INRs      M   33           9                       1900.0
# 22  PD-H238  INRs      M   67           7                      11800.0
# 23  PD-H240  INRs      M   36           8                          0.0
# 24  PD-H241  INRs      M   43           9                        112.0
# 25  PD-H242  INRs      M   72          10                          0.0
# 26  PD-H246  INRs      M   40           5                       4500.0
# 27  PD-H247  INRs      M   35           7                        149.0
# 28  PD-H255  INRs      M   71          10                          0.0
# 29  PD-H258  INRs      M   36           7                         55.4
# 30  PD-H260  INRs      M   50          10                          0.0
# 31  PD-H263  INRs      M   31           5                      10511.0
# 32  PD-H264  INRs      M   38           7                       1180.0
# 33  PD-H265  INRs      M   39           9                          0.0
# 34  PD-H266  INRs      M   43           5                        545.0
# 35  PD-H276  INRs      M   61           4                      13400.0
# 36  PD-H277  INRs      M   55           9                          0.0
# 37  PD-H278  INRs      M   52           6                          0.0
# 38  PD-H281  INRs      M   37           6                       2980.0
# 39  PD-H285  INRs      M   39           5                    3315000.0
# 40  PD-H286  INRs      M   57          10                          0.0
# 41  PD-H288  INRs      M   33           5                          0.0
# 42  PD-H289  INRs      M   34           5                          0.0
#
#     Viral load (cp/mL)  Baseline CD4 count (/μL)  CD4 count (/μL)  \
# 0                 25.1                        34              206
# 1                  0.0                        56              128
# 2                  0.0                       122              252
# 3                  0.0                         1              269
# 4                  0.0                        56              240
# 5                  0.0                        32              151
# 6                  0.0                       182              282
# 7                  0.0                        29              175
# 8                  0.0                        13              208
# 9                  0.0                        12              124
# 10                23.2                        36              156
# 11                 0.0                       102              129
# 12                 0.0                        34              108
# 13                 0.0                       209              262
# 14                 0.0                        16              257
# 15                 0.0                       100              261
# 16                 0.0                       106              161
# 17                 0.0                         4              200
# 18                 0.0                       112              199
# 19                 0.0                        93              175
# 20                 0.0                        15              239
# 21                 0.0                       145              241
# 22                 0.0                        60              101
# 23                 0.0                        47              260
# 24                 0.0                       240              131
# 25                 0.0                        72              229
# 26                 0.0                        43              240
# 27                 0.0                        49              240
# 28                 0.0                        18              211
# 29                 0.0                        29              235
# 30                 0.0                       150              210
# 31                 0.0                       139              249
# 32                 0.0                       279              132
# 33                 0.0                        13              174
# 34                 0.0                        41              229
# 35                 0.0                        22              196
# 36                 0.0                       100              245
# 37                 0.0                        52              148
# 38                 0.0                         9              258
# 39                 0.0                        22              263
# 40                 0.0                        19              206
# 41                 0.0                       134              236
# 42                 0.0                        32              229
#
#     CD8 count(/μL)  CD4/CD8 Ratio    ART regimen INSTI
# 0              700       0.294286    BIC/FTC/TAF   Yes
# 1              338       0.378698    3TC+EFV+TDF    No
# 2              652       0.386503    AZT/3TC+NVP    No
# 3              512       0.525391    3TC+EFV+TDF    No
# 4             1010       0.237624    BIC/FTC/TAF   Yes
# 5              569       0.265378    3TC+EFV+TDF    No
# 6              552       0.510870    BIC/FTC/TAF   Yes
# 7              320       0.546875    3TC+EFV+TDF    No
# 8              881       0.236095    BIC/FTC/TAF   Yes
# 9              374       0.331551    BIC/FTC/TAF   Yes
# 10             355       0.439437    BIC/FTC/TAF   Yes
# 11             280       0.460714    3TC+EFV+TDF    No
# 12             451       0.239468  EVG/c/FTC/TAF   Yes
# 13             594       0.441077    AZT/3TC+NVP    No
# 14             393       0.653944    BIC/FTC/TAF   Yes
# 15             659       0.396055    BIC/FTC/TAF   Yes
# 16            1060       0.151887    BIC/FTC/TAF   Yes
# 17             747       0.267738    BIC/FTC/TAF   Yes
# 18             193       1.031088    3TC+EFV+TDF    No
# 19             810       0.216049    BIC/FTC/TAF   Yes
# 20             643       0.371695    BIC/FTC/TAF   Yes
# 21             337       0.715134    BIC/FTC/TAF   Yes
# 22             374       0.270053    AZT/3TC+NVP    No
# 23             474       0.548523    3TC+EFV+TDF    No
# 24             686       0.190962      3TC+LPV/r    No
# 25             321       0.713396    AZT/3TC+NVP    No
# 26             774       0.310078    3TC+EFV+TDF    No
# 27             667       0.359820    BIC/FTC/TAF   Yes
# 28             177       1.192090    3TC+EFV+TDF    No
# 29             605       0.388430    BIC/FTC/TAF   Yes
# 30             385       0.545455    AZT/3TC+EFV    No
# 31             623       0.399679  EVG/c/FTC/TAF   Yes
# 32             664       0.198795        3TC/DTG   Yes
# 33             586       0.296928    BIC/FTC/TAF   Yes
# 34             445       0.514607    BIC/FTC/TAF   Yes
# 35             433       0.452656    BIC/FTC/TAF   Yes
# 36             476       0.514706    AZT/3TC+EFV    No
# 37             413       0.358354    AZT/3TC+EFV    No
# 38             862       0.299304    3TC+EFV+TDF    No
# 39             816       0.322304    3TC+EFV+TDF    No
# 40             551       0.373866    AZT/3TC+EFV    No
# 41             371       0.636119        3TC/DTG   Yes
# 42             823       0.278250    BIC/FTC/TAF   Yes
