# %%
#细胞划分训练测试验证
import scanpy as sc
adata=sc.read_h5ad('./data/adata_process.h5ad')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
adata.obs['HIV_label'] = le.fit_transform(adata.obs['stage'])

X = range(adata.shape[0])
y = adata.obs['HIV_label']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, stratify=y
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, stratify=y_train
)
#all:1
#train:0.7*0.8=0.56
#val:0.7*0.2=0.14
#test:0.3

# %%
dict_fen={'train':X_train,'val':X_val,'test':X_test}
import pickle
def save_data(data, filename):
    with open(filename, 'wb') as f:
        pickle.dump(data, f)
    print(f"Data saved to {filename}")

# 定义一个函数，用于加载文件中的数据
# 定义一个函数，用于加载文件中的数据
    # 打开文件，以二进制模式读取
def load_data(filename):
        # 使用pickle模块加载文件中的数据
    with open(filename, 'rb') as f:
    # 返回加载的数据
        data = pickle.load(f)
    return data
# save_data(dict_fen,'/home/share/huadjyin/home/zhouxuanchi/HIV/atac_to_gene_new_data_0218/data/fen.pkl')
save_data(dict_fen,'./data/fen.pkl')
