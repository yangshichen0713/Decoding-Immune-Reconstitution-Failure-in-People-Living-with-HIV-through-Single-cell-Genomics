# %%
import pandas as pd

# %%
import pickle
def save_data(data, filename):
    with open(filename, 'wb') as f:
        pickle.dump(data, f)
    print(f"Data saved to {filename}")
    
# 定义一个函数，用于加载文件中的数据
# 定义一个函数，用于加载文件中的数据
    # 打开文件，以二进制模式读取
def load_data(filename):
        # 使用pickle模块加载文件中的数据
    with open(filename, 'rb') as f:
    # 返回加载的数据
        data = pickle.load(f)
    return data

# %%
import scanpy as sc
adata=sc.read_h5ad('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak2gene/data/adata_process.h5ad',backed='r')

# %%
dict_sample_cell= load_data('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/HDs_INRs_IG/data/dict_sample_cell.pkl')
gene_list=list(adata.var_names[:582])

# %%
ig_output_path='/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/HDs_INRs_IG/output'
list_all=[]
import os
list_test_samples=os.listdir(ig_output_path)
for sample in list_test_samples:
    dt=load_data(ig_output_path+'/'+sample)
    dt=np.concatenate (dt['gene'])
    list_all.append(dt)
dt=np.concatenate(list_all)
ig_mean=np.mean(np.abs(dt),axis=0)
sorted_indices = np.argsort(ig_mean)[::-1]
hds_inrs_top60=[]
for i in sorted_indices[:60]:
    hds_inrs_top60.append(gene_list[i])

# %%
save_data(hds_inrs_top60,'/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_inrs_top60.pkl')
# Out:
# Data saved to /home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_inrs_top60.pkl

# %%
ig_output_path='/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/HDs_IRs_IG/output'
list_all=[]
import os
list_test_samples=os.listdir(ig_output_path)
for sample in list_test_samples:
    dt=load_data(ig_output_path+'/'+sample)
    dt=np.concatenate (dt['gene'])
    list_all.append(dt)
dt=np.concatenate(list_all)
ig_mean=np.mean(np.abs(dt),axis=0)
sorted_indices = np.argsort(ig_mean)[::-1]
hds_irs_top60=[]
for i in sorted_indices[:60]:
    hds_irs_top60.append(gene_list[i])

# %%
save_data(hds_irs_top60,'/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_irs_top60.pkl')
# Out:
# Data saved to /home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_irs_top60.pkl

# %%
ig_output_path='/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/IRs_INRs_IG/output'
list_all=[]
import os
list_test_samples=os.listdir(ig_output_path)
for sample in list_test_samples:
    dt=load_data(ig_output_path+'/'+sample)
    dt=np.concatenate (dt['gene'])
    list_all.append(dt)
dt=np.concatenate(list_all)
ig_mean=np.mean(np.abs(dt),axis=0)
sorted_indices = np.argsort(ig_mean)[::-1]
irs_inrs_top60=[]
for i in sorted_indices[:60]:
    irs_inrs_top60.append(gene_list[i])

# %%
save_data(irs_inrs_top60,'/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/irs_inrs_top60.pkl')
# Out:
# Data saved to /home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/irs_inrs_top60.pkl

# %%
import pickle
def save_data(data, filename):
    with open(filename, 'wb') as f:
        pickle.dump(data, f)
    print(f"Data saved to {filename}")
    
# 定义一个函数，用于加载文件中的数据
# 定义一个函数，用于加载文件中的数据
    # 打开文件，以二进制模式读取
def load_data(filename):
        # 使用pickle模块加载文件中的数据
    with open(filename, 'rb') as f:
    # 返回加载的数据
        data = pickle.load(f)
    return data

import pandas as pd
hds_inrs_top60=load_data('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_inrs_top60.pkl')
hds_irs_top60=load_data('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_irs_top60.pkl')
irs_inrs_top60=load_data('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/irs_inrs_top60.pkl')
set1=set(hds_inrs_top60)
set2=set(hds_irs_top60)
set3=set(irs_inrs_top60)
seperman=pd.read_csv('/home/share/huadjyin/home/lutianyu/01HIV/02data/downstream/peak2gene/spearman_correlation_mse.csv')
gene_list=seperman['Gene_Symbol'][:60].tolist()
set4=set(gene_list)
interset=set4.intersection(set1,set2,set3)

# %%
len(interset)
# Out:
# 32

# %%
df_hds_inrs_mean=pd.read_csv('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_inrs/gene_mean_values.csv')
df_hds_irs_mean=pd.read_csv('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/hds_irs/gene_mean_values.csv')
df_irs_inrs_mean=pd.read_csv('/home/share/huadjyin/home/zhouxuanchi/HIV_code/peak_and_gene_to_stage/Figure/data/irs_inrs/gene_mean_values.csv')

# %%
df_hds_inrs_mean['task_celltype']='hds_inrs'+df_hds_inrs_mean['celltype_L1']
df_hds_irs_mean['task_celltype']='hds_irs'+df_hds_irs_mean['celltype_L1']
df_irs_inrs_mean['task_celltype']='irs_inrs'+df_irs_inrs_mean['celltype_L1']

# %%
df_all=pd.concat([df_irs_inrs_mean,df_hds_inrs_mean,df_hds_irs_mean])

# %%
df_all = df_all.sort_values(by='celltype_L1')

# %%
df_all=df_all.loc[:,list(interset)+['task_celltype']]
df_all = df_all.set_index('task_celltype')

# %%
df_normalized = df_all.apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
colors = ["#062456","#1d3867","#334d77","#4a6188","#627799","#7a8ca9","#93a2ba","#adb9cb","#c8d0dc","#e3e7ee"] 
colors = colors[::-1]
import matplotlib.colors as mcolors
cmap = mcolors.LinearSegmentedColormap.from_list("custom_cmap", colors)
import matplotlib.pyplot as plt
import seaborn as sns
sns.clustermap(df_normalized, cmap=cmap, figsize=(20, 8), row_cluster=False,vmin=0,vmax=1)

# 显示图形
plt.show()
