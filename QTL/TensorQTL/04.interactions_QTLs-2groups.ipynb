# %% [markdown]
# ### author by yangshichen
# ### 注意：脚本仅供参考，使用前请仔细阅读

# %%
import os
import scanpy as sc
import anndata as ad
import numpy as np
import pandas as pd
import seaborn as sb
import seaborn as sns
from matplotlib.pyplot import rc_context
import matplotlib.pyplot as plt
from scipy.io import mmread
from scipy.sparse import csr_matrix
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
from scipy.sparse import issparse
import decoupler as dc
from sklearn.preprocessing import QuantileTransformer
from multiprocessing import Pool, cpu_count
from functools import partial
from sklearn.preprocessing import QuantileTransformer, StandardScaler
quantile_transformer = QuantileTransformer(output_distribution='normal', random_state=0)
scaler = StandardScaler()

import warnings
warnings.filterwarnings("ignore")

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=100, frameon=False)
sc._settings.ScanpyConfig.n_jobs=70
# Out:
# scanpy==1.9.8 anndata==0.9.2 umap==0.5.7 numpy==1.24.4 scipy==1.10.1 pandas==2.0.3 scikit-learn==1.3.2 statsmodels==0.14.1 pynndescent==0.5.13

# %%
import os
os.environ["R_HOME"] = "/home/yangshichen//mambaforge/envs/QTL/lib/R"
os.environ["R_LIBS_USER"] = "/home/yangshichen/mambaforge/envs/QTL/lib/R/library"
import pandas as pd
import torch
import tensorqtl
from tensorqtl import  cis
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"torch: {torch.__version__} (CUDA {torch.version.cuda}), device: {device}")
print(f"pandas: {pd.__version__}")
# Out:
# Warning: 'rfunc' cannot be imported. R with the 'qvalue' library and the 'rpy2' Python package are needed to compute q-values.
# torch: 2.4.1+cu121 (CUDA 12.1), device: cuda
# pandas: 2.0.3

# %% [markdown]
# ### cis-eQTL mapping: interactions（disease status影响SNP对gene的表达）

# %%
#Read genotype_df and vatiant_df
genotype_df = pd.read_parquet('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/01.Genotype/142_sample_genotype.parquet')
variant_df = pd.read_parquet('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/01.Genotype/142_sample_variant_df.parquet')

# %%
#设置bed文件所在的文件夹路径
bed_dir = '/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/02.scRNA-seq/01.pseudobulk/06.gene_expression_bed/'
output_dir = '/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/03.Result/eQTL/'

#获取所有以.bed结尾的文件
bed_files = [f for f in os.listdir(bed_dir) if f.endswith('.bed')]
bed_files
# Out:
# ['CD8_Naive_T-CCR7.bed',
#  'ncMono-FCGR3A.bed',
#  'Aptypical_Memory_B-ITGAX.bed',
#  'CD4_Naive_T-CCR7.bed',
#  'CD4_Naive_T-SOX4.bed',
#  'CD4_Tcm-CXCR5.bed',
#  'CD4_Tcm-GPR183.bed',
#  'CD4_Tcm-IFIT3.bed',
#  'CD4_Tcm-SOX4.bed',
#  'CD4_Tem-CCR7neg.bed',
#  'CD4_Tfh_like-CXCR5.bed',
#  'CD4_Th-TNFRSF11A.bed',
#  'CD4_Th1-GZMK.bed',
#  'CD4_Th17-RORC.bed',
#  'CD4_Th22-CCR10.bed',
#  'CD4_Treg-FCRL3.bed',
#  'CD4_Treg-FOXP3.bed',
#  'CD8_CTL-GZMB.bed',
#  'CD8_CTL-GZMK.bed',
#  'ncMono-IFI44L.bed',
#  'ncMono-IFIT1.bed',
#  'NKT-IFIT3.bed',
#  'NKT-NCR1.bed',
#  'NK_bright-XCL1.bed',
#  'pDC-LILRA4.bed',
#  'Plasma_B-IGHA1.bed',
#  'Switched_Memory_B-CD27.bed',
#  'Switched_Memory_B-CD86.bed',
#  'Switched_Memory_B-IGHE.bed',
#  'Terminal_NK_dim-CD160neg.bed',
#  'Transitional_B-NEIL1.bed',
#  'Transitional_NK-GZMK.bed',
#  'Unswitched_Memory_B-CD1C.bed',
#  'Unswitched_Memory_B-IFIT3.bed',
#  'Unswitched_Memory_B-JAM3.bed',
#  'CD8_Tcm-GPR183.bed',
#  'CD8_Tcm-GZMK.bed',
#  'CD8_Tcm-IFI44L.bed',
#  'CD8_Tem-GZMK.bed',
#  'cDC2-CD1C.bed',
#  'cMono-CD14.bed',
#  'cMono-IFI44L.bed',
#  'Cycling_T-MKI67.bed',
#  'gdT2-GZMH.bed',
#  'gdT2-GZMK.bed',
#  'gdT2-IL12RB2.bed',
#  'MAIT-SLC4A10.bed',
#  'Mature_NK_dim-FCGR3A.bed',
#  'Naive_B-IFIT3.bed',
#  'Naive_B-TCL1A.bed',
#  'ncMono-C1QA.bed']

# %%
# 遍历文件，处理并创建对应文件夹
for bed_file in bed_files:
    try:
        cell_name = os.path.splitext(bed_file)[0]  # 去掉.bed后缀
        folder_path = os.path.join(output_dir, cell_name)

        # read_expression_file and covariates
        expression_bed = f'/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/02.scRNA-seq/01.pseudobulk/06.gene_expression_bed/{cell_name}.bed'
        covariates_file = f'/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/02.scRNA-seq/01.pseudobulk/05.PEER/01.factor/{cell_name}.csv'

        # load phenotypes and covariates
        phenotype_df, phenotype_pos_df = tensorqtl.read_phenotype_bed(expression_bed)
        covariates_df = pd.read_csv(covariates_file, sep=',', index_col=0)
        phenotype_df = phenotype_df[covariates_df.index]

        # cis-QTL mapping with interaction
        interaction_df = covariates_df[['stage']].copy()
        interaction_df['stage'] = interaction_df['stage'].replace({1: 0, 2: 1})  # HDs和IRs合并
        covariates_df_new = covariates_df.drop(columns=['stage'])

        os.makedirs(f'{folder_path}/diseases_2groups/', exist_ok=True)
        cis.map_nominal(genotype_df, variant_df, phenotype_df, phenotype_pos_df, 'diseases_2groups',
                        covariates_df=covariates_df_new, interaction_df=interaction_df,
                        maf_threshold_interaction=0.1, run_eigenmt=True,
                        output_dir=f'{folder_path}/diseases_2groups/', write_top=True, write_stats=True)
    except Exception as e:
        print(f"跳过 {bed_file}，错误信息: {e}")
        continue
# Out:
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 11197 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 11197/11197
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1174/11188    time elapsed: 1.38 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1939/11188    time elapsed: 2.40 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2583/11188    time elapsed: 3.21 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2979/11188    time elapsed: 3.79 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 3476/11188    time elapsed: 4.46 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 4059/11188    time elapsed: 5.13 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 4609/11188    time elapsed: 5.87 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4990/11188    time elapsed: 6.35 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 5436/11188    time elapsed: 6.93 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 5876/11188    time elapsed: 7.55 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 6536/11188    time elapsed: 8.40 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 7170/11188    time elapsed: 9.21 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 7378/11188    time elapsed: 9.52 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 7803/11188    time elapsed: 10.08 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 8169/11188    time elapsed: 10.53 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 8699/11188    time elapsed: 11.25 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 9413/11188    time elapsed: 12.05 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 9563/11188    time elapsed: 12.29 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 10467/11188    time elapsed: 13.52 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 10778/11188    time elapsed: 13.97 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 10893/11188    time elapsed: 14.15 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 11188/11188
#     time elapsed: 14.53 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 9314 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9314/9314
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 985/9306    time elapsed: 1.08 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1615/9306    time elapsed: 1.87 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2146/9306    time elapsed: 2.52 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2484/9306    time elapsed: 3.01 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2899/9306    time elapsed: 3.53 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3389/9306    time elapsed: 4.12 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3832/9306    time elapsed: 4.71 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4146/9306    time elapsed: 5.09 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4529/9306    time elapsed: 5.57 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4895/9306    time elapsed: 6.09 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5461/9306    time elapsed: 6.75 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5986/9306    time elapsed: 7.43 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6164/9306    time elapsed: 7.72 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 6502/9306    time elapsed: 8.16 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6796/9306    time elapsed: 8.50 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7243/9306    time elapsed: 9.03 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7853/9306    time elapsed: 9.72 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7975/9306    time elapsed: 9.92 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 8691/9306    time elapsed: 10.89 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8959/9306    time elapsed: 11.28 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 9055/9306    time elapsed: 11.42 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 9306/9306
#     time elapsed: 11.72 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 141 samples
#   * 7100 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 7100/7100
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 780/7092    time elapsed: 0.89 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1281/7092    time elapsed: 1.56 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1697/7092    time elapsed: 2.09 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 1951/7092    time elapsed: 2.48 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2279/7092    time elapsed: 2.90 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 2667/7092    time elapsed: 3.36 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3008/7092    time elapsed: 3.83 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3246/7092    time elapsed: 4.14 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 3523/7092    time elapsed: 4.53 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 3814/7092    time elapsed: 4.93 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4236/7092    time elapsed: 5.43 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 4635/7092    time elapsed: 5.96 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 4768/7092    time elapsed: 6.18 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5034/7092    time elapsed: 6.53 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 5263/7092    time elapsed: 6.81 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 5587/7092    time elapsed: 7.20 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 6037/7092    time elapsed: 7.73 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 6130/7092    time elapsed: 7.89 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 6629/7092    time elapsed: 8.57 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 6828/7092    time elapsed: 8.85 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 6897/7092    time elapsed: 8.96 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 7092/7092
#     time elapsed: 9.20 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 10529 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 10529/10529
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1093/10520    time elapsed: 1.29 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1830/10520    time elapsed: 2.22 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2434/10520    time elapsed: 2.97 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2808/10520    time elapsed: 3.55 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 3275/10520    time elapsed: 4.16 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3832/10520    time elapsed: 4.82 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 4346/10520    time elapsed: 5.51 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4705/10520    time elapsed: 6.00 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 5126/10520    time elapsed: 6.60 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 5537/10520    time elapsed: 7.23 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 6160/10520    time elapsed: 8.00 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 6753/10520    time elapsed: 8.81 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6952/10520    time elapsed: 9.14 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 7345/10520    time elapsed: 9.65 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 7678/10520    time elapsed: 10.11 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 8189/10520    time elapsed: 10.73 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 8862/10520    time elapsed: 11.50 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 9003/10520    time elapsed: 11.74 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 9845/10520    time elapsed: 12.90 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 10138/10520    time elapsed: 13.34 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 10250/10520    time elapsed: 13.52 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 10520/10520
#     time elapsed: 13.87 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 137 samples
#   * 7021 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 7021/7021
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 752/7013    time elapsed: 0.91 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1269/7013    time elapsed: 1.56 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1674/7013    time elapsed: 2.09 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 1924/7013    time elapsed: 2.47 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2261/7013    time elapsed: 2.91 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 2623/7013    time elapsed: 3.33 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 2966/7013    time elapsed: 3.78 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3190/7013    time elapsed: 4.08 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 3474/7013    time elapsed: 4.47 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 3756/7013    time elapsed: 4.90 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4166/7013    time elapsed: 5.44 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 4575/7013    time elapsed: 6.02 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 4707/7013    time elapsed: 6.24 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 4958/7013    time elapsed: 6.62 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 5179/7013    time elapsed: 6.89 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 5504/7013    time elapsed: 7.29 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 5961/7013    time elapsed: 7.81 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 6056/7013    time elapsed: 7.97 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 6546/7013    time elapsed: 8.68 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 6752/7013    time elapsed: 8.99 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 6827/7013    time elapsed: 9.14 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 7013/7013
#     time elapsed: 9.37 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 9432 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9432/9432
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 980/9423    time elapsed: 1.15 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1636/9423    time elapsed: 2.03 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2177/9423    time elapsed: 2.71 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2515/9423    time elapsed: 3.23 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2935/9423    time elapsed: 3.80 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3430/9423    time elapsed: 4.34 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3894/9423    time elapsed: 5.00 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4218/9423    time elapsed: 5.43 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4593/9423    time elapsed: 5.93 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4964/9423    time elapsed: 6.52 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5522/9423    time elapsed: 7.21 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 6057/9423    time elapsed: 7.91 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6238/9423    time elapsed: 8.20 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 6588/9423    time elapsed: 8.74 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6889/9423    time elapsed: 9.12 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7345/9423    time elapsed: 9.66 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7955/9423    time elapsed: 10.39 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 8078/9423    time elapsed: 10.60 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 8812/9423    time elapsed: 11.71 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 9076/9423    time elapsed: 12.11 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 9177/9423    time elapsed: 12.29 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 9423/9423
#     time elapsed: 12.58 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 8253 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 8253/8253
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 873/8244    time elapsed: 1.01 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1461/8244    time elapsed: 1.78 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1941/8244    time elapsed: 2.37 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2242/8244    time elapsed: 2.83 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2618/8244    time elapsed: 3.33 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3048/8244    time elapsed: 3.80 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3453/8244    time elapsed: 4.35 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3731/8244    time elapsed: 4.77 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4055/8244    time elapsed: 5.21 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4385/8244    time elapsed: 5.70 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4877/8244    time elapsed: 6.31 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5351/8244    time elapsed: 6.93 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5507/8244    time elapsed: 7.20 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5801/8244    time elapsed: 7.61 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6064/8244    time elapsed: 7.94 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 6457/8244    time elapsed: 8.44 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 6990/8244    time elapsed: 9.08 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7101/8244    time elapsed: 9.28 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 7703/8244    time elapsed: 10.13 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 7941/8244    time elapsed: 10.47 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8027/8244    time elapsed: 10.61 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 8244/8244
#     time elapsed: 10.86 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 141 samples
#   * 6554 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 6554/6554
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 692/6546    time elapsed: 0.80 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1183/6546    time elapsed: 1.46 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1567/6546    time elapsed: 1.94 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 1808/6546    time elapsed: 2.32 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2113/6546    time elapsed: 2.75 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 2453/6546    time elapsed: 3.25 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 2776/6546    time elapsed: 3.75 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 2982/6546    time elapsed: 4.03 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 3237/6546    time elapsed: 4.38 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 3494/6546    time elapsed: 4.74 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 3886/6546    time elapsed: 5.22 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 4277/6546    time elapsed: 5.76 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 4406/6546    time elapsed: 5.97 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 4650/6546    time elapsed: 6.30 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 4856/6546    time elapsed: 6.59 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 5163/6546    time elapsed: 6.98 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 5598/6546    time elapsed: 7.52 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 5691/6546    time elapsed: 7.68 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 6112/6546    time elapsed: 8.25 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 6304/6546    time elapsed: 8.53 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 6370/6546    time elapsed: 8.64 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 6546/6546
#     time elapsed: 8.84 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 138 samples
#   * 7313 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 7313/7313
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 780/7305    time elapsed: 0.93 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1308/7305    time elapsed: 1.63 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1733/7305    time elapsed: 2.17 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 1997/7305    time elapsed: 2.60 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2337/7305    time elapsed: 3.05 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 2719/7305    time elapsed: 3.49 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3082/7305    time elapsed: 4.00 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3321/7305    time elapsed: 4.33 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 3611/7305    time elapsed: 4.73 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 3903/7305    time elapsed: 5.11 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4335/7305    time elapsed: 5.68 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 4763/7305    time elapsed: 6.28 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 4904/7305    time elapsed: 6.51 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5169/7305    time elapsed: 6.88 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 5408/7305    time elapsed: 7.18 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 5752/7305    time elapsed: 7.63 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 6223/7305    time elapsed: 8.20 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 6319/7305    time elapsed: 8.37 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 6824/7305    time elapsed: 9.14 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 7038/7305    time elapsed: 9.51 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 7115/7305    time elapsed: 9.64 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 7305/7305
#     time elapsed: 9.88 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 140 samples
#   * 7655 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 7655/7655
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 823/7647    time elapsed: 0.93 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1374/7647    time elapsed: 1.67 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1826/7647    time elapsed: 2.34 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2104/7647    time elapsed: 2.88 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2457/7647    time elapsed: 3.36 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 2860/7647    time elapsed: 3.83 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3236/7647    time elapsed: 4.37 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3487/7647    time elapsed: 4.72 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 3793/7647    time elapsed: 5.10 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4099/7647    time elapsed: 5.56 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4548/7647    time elapsed: 6.14 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 4984/7647    time elapsed: 6.72 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5132/7647    time elapsed: 7.00 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5404/7647    time elapsed: 7.38 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 5653/7647    time elapsed: 7.70 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 6014/7647    time elapsed: 8.25 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 6505/7647    time elapsed: 8.81 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 6608/7647    time elapsed: 8.98 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 7143/7647    time elapsed: 9.86 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 7365/7647    time elapsed: 10.18 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 7445/7647    time elapsed: 10.31 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 7647/7647
#     time elapsed: 10.60 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 141 samples
#   * 9106 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9106/9106
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 957/9097    time elapsed: 1.18 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1595/9097    time elapsed: 2.04 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2120/9097    time elapsed: 2.73 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2446/9097    time elapsed: 3.19 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2854/9097    time elapsed: 3.74 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3334/9097    time elapsed: 4.33 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3781/9097    time elapsed: 4.94 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4088/9097    time elapsed: 5.36 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4450/9097    time elapsed: 5.87 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4813/9097    time elapsed: 6.39 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5348/9097    time elapsed: 7.09 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5870/9097    time elapsed: 7.79 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6048/9097    time elapsed: 8.08 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 6378/9097    time elapsed: 8.57 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6666/9097    time elapsed: 8.94 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7105/9097    time elapsed: 9.48 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7696/9097    time elapsed: 10.13 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7818/9097    time elapsed: 10.34 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 8505/9097    time elapsed: 11.34 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8760/9097    time elapsed: 11.73 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8858/9097    time elapsed: 11.87 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 9097/9097
#     time elapsed: 12.21 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 139 samples
#   * 8331 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 8331/8331
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 887/8322    time elapsed: 1.09 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1480/8322    time elapsed: 1.88 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1970/8322    time elapsed: 2.49 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2273/8322    time elapsed: 2.96 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2652/8322    time elapsed: 3.46 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3091/8322    time elapsed: 3.97 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3494/8322    time elapsed: 4.56 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3763/8322    time elapsed: 4.90 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4093/8322    time elapsed: 5.36 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4428/8322    time elapsed: 5.85 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4932/8322    time elapsed: 6.50 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5408/8322    time elapsed: 7.15 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5570/8322    time elapsed: 7.43 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5868/8322    time elapsed: 7.83 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6135/8322    time elapsed: 8.16 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 6527/8322    time elapsed: 8.63 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7065/8322    time elapsed: 9.26 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7180/8322    time elapsed: 9.46 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 7783/8322    time elapsed: 10.35 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8020/8322    time elapsed: 10.71 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8106/8322    time elapsed: 10.85 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 8322/8322
#     time elapsed: 11.12 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 140 samples
#   * 8428 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 8428/8428
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 901/8419    time elapsed: 1.03 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1500/8419    time elapsed: 1.84 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1997/8419    time elapsed: 2.45 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2302/8419    time elapsed: 2.93 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2682/8419    time elapsed: 3.51 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3124/8419    time elapsed: 4.00 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3533/8419    time elapsed: 4.59 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3808/8419    time elapsed: 5.00 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4145/8419    time elapsed: 5.52 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4481/8419    time elapsed: 5.98 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4983/8419    time elapsed: 6.65 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5468/8419    time elapsed: 7.33 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5631/8419    time elapsed: 7.63 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5933/8419    time elapsed: 8.05 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6204/8419    time elapsed: 8.40 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 6610/8419    time elapsed: 8.91 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7156/8419    time elapsed: 9.58 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7271/8419    time elapsed: 9.78 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 7880/8419    time elapsed: 10.73 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8116/8419    time elapsed: 11.10 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8201/8419    time elapsed: 11.26 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 8419/8419
#     time elapsed: 11.53 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 141 samples
#   * 9026 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9026/9026
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 958/9017    time elapsed: 1.07 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1588/9017    time elapsed: 1.92 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2120/9017    time elapsed: 2.62 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2446/9017    time elapsed: 3.17 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2855/9017    time elapsed: 3.72 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3330/9017    time elapsed: 4.28 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3761/9017    time elapsed: 4.91 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4068/9017    time elapsed: 5.32 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4433/9017    time elapsed: 5.82 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4790/9017    time elapsed: 6.35 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5329/9017    time elapsed: 7.06 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5835/9017    time elapsed: 7.76 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6009/9017    time elapsed: 8.05 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 6338/9017    time elapsed: 8.53 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6625/9017    time elapsed: 8.90 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7059/9017    time elapsed: 9.53 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7637/9017    time elapsed: 10.21 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7762/9017    time elapsed: 10.48 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 8439/9017    time elapsed: 11.59 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8691/9017    time elapsed: 11.97 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8785/9017    time elapsed: 12.12 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 9017/9017
#     time elapsed: 12.41 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 9015 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9015/9015
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 948/9006    time elapsed: 1.07 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1578/9006    time elapsed: 1.90 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2114/9006    time elapsed: 2.54 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2436/9006    time elapsed: 3.05 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2841/9006    time elapsed: 3.61 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3310/9006    time elapsed: 4.19 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3741/9006    time elapsed: 4.84 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4042/9006    time elapsed: 5.24 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4402/9006    time elapsed: 5.74 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4761/9006    time elapsed: 6.27 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5307/9006    time elapsed: 7.00 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5819/9006    time elapsed: 7.66 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5992/9006    time elapsed: 7.94 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 6317/9006    time elapsed: 8.38 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6608/9006    time elapsed: 8.74 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7048/9006    time elapsed: 9.28 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7637/9006    time elapsed: 9.95 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7762/9006    time elapsed: 10.15 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 8425/9006    time elapsed: 11.06 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8677/9006    time elapsed: 11.45 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8771/9006    time elapsed: 11.60 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 9006/9006
#     time elapsed: 11.89 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 141 samples
#   * 7799 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 7799/7799
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 832/7790    time elapsed: 0.99 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1395/7790    time elapsed: 1.75 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1843/7790    time elapsed: 2.31 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2123/7790    time elapsed: 2.75 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2484/7790    time elapsed: 3.17 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 2895/7790    time elapsed: 3.65 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3274/7790    time elapsed: 4.18 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3526/7790    time elapsed: 4.53 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 3839/7790    time elapsed: 4.97 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4152/7790    time elapsed: 5.43 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4608/7790    time elapsed: 6.01 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5062/7790    time elapsed: 6.56 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5211/7790    time elapsed: 6.81 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5493/7790    time elapsed: 7.21 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 5746/7790    time elapsed: 7.54 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 6114/7790    time elapsed: 8.01 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 6609/7790    time elapsed: 8.63 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 6718/7790    time elapsed: 8.80 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 7276/7790    time elapsed: 9.56 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 7496/7790    time elapsed: 9.92 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 7579/7790    time elapsed: 10.07 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 7790/7790
#     time elapsed: 10.34 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 8339 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 8339/8339
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 884/8330    time elapsed: 1.05 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1482/8330    time elapsed: 1.98 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1965/8330    time elapsed: 2.62 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2267/8330    time elapsed: 3.10 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2641/8330    time elapsed: 3.60 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3090/8330    time elapsed: 4.16 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3494/8330    time elapsed: 4.72 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 3769/8330    time elapsed: 5.06 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4098/8330    time elapsed: 5.54 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4434/8330    time elapsed: 6.11 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 4930/8330    time elapsed: 6.89 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 5413/8330    time elapsed: 7.56 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 5578/8330    time elapsed: 7.83 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 5882/8330    time elapsed: 8.25 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6144/8330    time elapsed: 8.63 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 6547/8330    time elapsed: 9.12 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7085/8330    time elapsed: 9.77 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7198/8330    time elapsed: 9.97 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 7789/8330    time elapsed: 10.78 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8019/8330    time elapsed: 11.11 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 8103/8330    time elapsed: 11.25 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 8330/8330
#     time elapsed: 11.54 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 11269 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 11269/11269
# ...
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 1742/4531    time elapsed: 2.28 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 1962/4531    time elapsed: 2.58 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 2090/4531    time elapsed: 2.74 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 2246/4531    time elapsed: 2.94 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 2425/4531    time elapsed: 3.25 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 2697/4531    time elapsed: 3.58 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 2967/4531    time elapsed: 3.89 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 3049/4531    time elapsed: 4.00 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 3218/4531    time elapsed: 4.22 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 3374/4531    time elapsed: 4.43 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 3583/4531    time elapsed: 4.72 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 3884/4531    time elapsed: 5.08 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 3947/4531    time elapsed: 5.29 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 4224/4531    time elapsed: 5.71 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 4371/4531    time elapsed: 5.93 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 4412/4531    time elapsed: 6.00 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 4531/4531
#     time elapsed: 6.16 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 9278 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9278/9278
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 974/9269    time elapsed: 1.17 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1620/9269    time elapsed: 2.05 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2159/9269    time elapsed: 2.73 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2500/9269    time elapsed: 3.25 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 2908/9269    time elapsed: 3.81 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3396/9269    time elapsed: 4.39 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 3837/9269    time elapsed: 4.95 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4152/9269    time elapsed: 5.36 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4529/9269    time elapsed: 5.87 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 4904/9269    time elapsed: 6.46 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5473/9269    time elapsed: 7.20 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 6009/9269    time elapsed: 7.90 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6181/9269    time elapsed: 8.17 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 6516/9269    time elapsed: 8.65 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 6814/9269    time elapsed: 9.02 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7255/9269    time elapsed: 9.66 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 7854/9269    time elapsed: 10.40 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 7978/9269    time elapsed: 10.62 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 8679/9269    time elapsed: 11.67 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 8938/9269    time elapsed: 12.07 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 9029/9269    time elapsed: 12.22 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 9269/9269
#     time elapsed: 12.51 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 10354 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 10354/10354
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1078/10345    time elapsed: 1.25 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1796/10345    time elapsed: 2.09 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2388/10345    time elapsed: 2.79 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2767/10345    time elapsed: 3.39 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 3233/10345    time elapsed: 4.02 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3774/10345    time elapsed: 4.69 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 4267/10345    time elapsed: 5.41 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4613/10345    time elapsed: 5.86 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 5038/10345    time elapsed: 6.48 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 5434/10345    time elapsed: 7.16 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 6051/10345    time elapsed: 7.98 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 6636/10345    time elapsed: 8.74 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6825/10345    time elapsed: 9.05 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 7200/10345    time elapsed: 9.58 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 7538/10345    time elapsed: 10.02 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 8034/10345    time elapsed: 10.65 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 8699/10345    time elapsed: 11.41 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 8844/10345    time elapsed: 11.66 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 9682/10345    time elapsed: 12.87 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 9974/10345    time elapsed: 13.32 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 10080/10345    time elapsed: 13.50 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 10345/10345
#     time elapsed: 13.84 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 111 samples
#   * 2672 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 2672/2672
#     ** dropping 2 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 298/2670    time elapsed: 0.39 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 499/2670    time elapsed: 0.66 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 647/2670    time elapsed: 0.85 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 737/2670    time elapsed: 1.00 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 875/2670    time elapsed: 1.17 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 1040/2670    time elapsed: 1.36 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 1175/2670    time elapsed: 1.52 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 1261/2670    time elapsed: 1.63 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 1340/2670    time elapsed: 1.73 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 1442/2670    time elapsed: 1.87 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 1600/2670    time elapsed: 2.09 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 1754/2670    time elapsed: 2.30 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 1813/2670    time elapsed: 2.39 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 1922/2670    time elapsed: 2.53 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 2014/2670    time elapsed: 2.65 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 2119/2670    time elapsed: 2.80 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 2279/2670    time elapsed: 3.00 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 2313/2670    time elapsed: 3.06 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 2494/2670    time elapsed: 3.44 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 2570/2670    time elapsed: 3.55 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 2602/2670    time elapsed: 3.60 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 2670/2670
#     time elapsed: 3.69 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 10344 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 10344/10344
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1067/10335    time elapsed: 1.28 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1784/10335    time elapsed: 2.25 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2380/10335    time elapsed: 3.01 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2756/10335    time elapsed: 3.60 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 3222/10335    time elapsed: 4.23 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3775/10335    time elapsed: 4.87 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 4269/10335    time elapsed: 5.60 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4630/10335    time elapsed: 6.07 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 5044/10335    time elapsed: 6.61 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 5439/10335    time elapsed: 7.17 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 6052/10335    time elapsed: 7.90 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 6633/10335    time elapsed: 8.71 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6827/10335    time elapsed: 9.04 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 7216/10335    time elapsed: 9.53 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 7546/10335    time elapsed: 9.91 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 8030/10335    time elapsed: 10.48 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 8685/10335    time elapsed: 11.34 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 8832/10335    time elapsed: 12.31 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 9668/10335    time elapsed: 13.50 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 9953/10335    time elapsed: 14.29 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 10061/10335    time elapsed: 14.47 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 10335/10335
#     time elapsed: 14.81 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 119 samples
#   * 5147 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 5147/5147
#     ** dropping 6 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 556/5141    time elapsed: 0.62 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 917/5141    time elapsed: 1.36 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 1209/5141    time elapsed: 1.68 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 1377/5141    time elapsed: 1.94 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 1623/5141    time elapsed: 2.27 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 1886/5141    time elapsed: 2.57 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 2129/5141    time elapsed: 2.92 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 2285/5141    time elapsed: 3.10 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 2487/5141    time elapsed: 3.38 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 2692/5141    time elapsed: 3.66 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 3023/5141    time elapsed: 4.08 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 3332/5141    time elapsed: 4.47 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 3424/5141    time elapsed: 4.62 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 3609/5141    time elapsed: 4.92 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 3773/5141    time elapsed: 5.13 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 4018/5141    time elapsed: 5.45 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 4372/5141    time elapsed: 5.86 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 4443/5141    time elapsed: 5.99 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 4803/5141    time elapsed: 6.49 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 4957/5141    time elapsed: 6.86 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 5007/5141    time elapsed: 6.94 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 5141/5141
#     time elapsed: 7.10 min
#     * writing output
# done.

# %% [markdown]
# ### cis-caQTL mapping: interactions（disease status影响SNP对peak的开放）

# %%
#Read genotype_df and vatiant_df
genotype_df = pd.read_parquet('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/01.Genotype/142_sample_genotype.parquet')
variant_df = pd.read_parquet('/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/01.Genotype/142_sample_variant_df.parquet')

# %%
#设置bed文件所在的文件夹路径
bed_dir = '/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/03.scATAC-seq/01.pseudobulk/06.peak_accessibility_bed/'
output_dir = '/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/03.Result/caQTL/'

#获取所有以.bed结尾的文件
bed_files = [f for f in os.listdir(bed_dir) if f.endswith('.bed')]

# %%
#Aptypical_Memory_B-ITGAX
bed_files
# Out:
# ['cMono-IFI44L.bed',
#  'Aptypical_Memory_B-ITGAX.bed',
#  'CD4_Naive_T-CCR7.bed',
#  'CD4_Tcm-CXCR5.bed',
#  'CD4_Tcm-GPR183.bed',
#  'CD4_Tem-CCR7neg.bed',
#  'CD4_Tfh_like-CXCR5.bed',
#  'CD4_Th-TNFRSF11A.bed',
#  'CD4_Th1-GZMK.bed',
#  'CD4_Th17-RORC.bed',
#  'CD4_Th22-CCR10.bed',
#  'CD4_Treg-FCRL3.bed',
#  'CD4_Treg-FOXP3.bed',
#  'CD8_CTL-GZMB.bed',
#  'CD8_CTL-GZMK.bed',
#  'CD8_Naive_T-CCR7.bed',
#  'CD8_Tcm-GZMK.bed',
#  'CD8_Tem-GZMK.bed',
#  'cDC2-CD1C.bed',
#  'cMono-CD14.bed',
#  'gdT2-GZMH.bed',
#  'MAIT-SLC4A10.bed',
#  'Mature_NK_dim-FCGR3A.bed',
#  'Naive_B-TCL1A.bed',
#  'ncMono-FCGR3A.bed',
#  'ncMono-IFI44L.bed',
#  'ncMono-IFIT1.bed',
#  'NKT-NCR1.bed',
#  'NK_bright-XCL1.bed',
#  'pDC-LILRA4.bed',
#  'Plasma_B-IGHA1.bed',
#  'Switched_Memory_B-CD27.bed',
#  'Switched_Memory_B-CD86.bed',
#  'Switched_Memory_B-IGHE.bed',
#  'Unswitched_Memory_B-CD1C.bed']

# %%
# 遍历文件，处理并创建对应文件夹
for bed_file in bed_files:
    try:
        cell_name = os.path.splitext(bed_file)[0]  # 去掉.bed后缀
        folder_path = os.path.join(output_dir, cell_name)

        # read_expression_file and covariates
        expression_bed = f'/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/03.scATAC-seq/01.pseudobulk/06.peak_accessibility_bed/{cell_name}.bed'
        covariates_file = f'/media/AnalysisDisk2/Yangshichen/0_HIV_RNA/QTL/01.Dynamic/01.Data/03.scATAC-seq/01.pseudobulk/05.PEER/01.factor/{cell_name}.csv'

        # load phenotypes and covariates
        phenotype_df, phenotype_pos_df = tensorqtl.read_phenotype_bed(expression_bed)
        covariates_df = pd.read_csv(covariates_file, sep=',', index_col=0)
        phenotype_df = phenotype_df[covariates_df.index]

        # cis-QTL mapping with interaction
        interaction_df = covariates_df[['stage']].copy()
        interaction_df['stage'] = interaction_df['stage'].replace({1: 0, 2: 1})  # HDs和IRs合并
        covariates_df_new = covariates_df.drop(columns=['stage'])

        os.makedirs(f'{folder_path}/diseases_2groups/', exist_ok=True)
        cis.map_nominal(genotype_df, variant_df, phenotype_df, phenotype_pos_df, 'diseases_2groups',
                        covariates_df=covariates_df_new, interaction_df=interaction_df,
                        maf_threshold_interaction=0.1, run_eigenmt=True,
                        output_dir=f'{folder_path}/diseases_2groups/', write_top=True, write_stats=True)
    except Exception as e:
        print(f"跳过 {bed_file}，错误信息: {e}")
        continue
# Out:
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 44003 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 44003/44003
#     ** dropping 27 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 4316/43976    time elapsed: 13.44 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 7698/43976    time elapsed: 24.94 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 10556/43976    time elapsed: 35.27 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 12309/43976    time elapsed: 42.80 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 14520/43976    time elapsed: 51.33 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 17062/43976    time elapsed: 60.93 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 19134/43976    time elapsed: 67.73 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 20951/43976    time elapsed: 76.60 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 22705/43976    time elapsed: 84.77 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 24783/43976    time elapsed: 93.33 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 27265/43976    time elapsed: 102.22 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 29710/43976    time elapsed: 110.71 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 30625/43976    time elapsed: 113.70 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 32103/43976    time elapsed: 118.98 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 33668/43976    time elapsed: 126.60 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 35423/43976    time elapsed: 133.88 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 38001/43976    time elapsed: 144.02 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 38808/43976    time elapsed: 148.85 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 41277/43976    time elapsed: 160.94 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 42434/43976    time elapsed: 165.17 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 42999/43976    time elapsed: 168.26 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 43976/43976
#     time elapsed: 173.15 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 98 samples
#   * 12848 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 12848/12848
#     ** dropping 13 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1230/12835跳过 Aptypical_Memory_B-ITGAX.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 37570 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 37570/37570
#     ** dropping 27 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 3829/37543    time elapsed: 14.57 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 6705/37543    time elapsed: 23.46 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 8981/37543    time elapsed: 29.84 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 10334/37543    time elapsed: 33.84 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 12132/37543    time elapsed: 39.11 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 14444/37543    time elapsed: 45.54 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 16226/37543    time elapsed: 51.21 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 17648/37543    time elapsed: 55.25 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 19073/37543    time elapsed: 58.81 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 20741/37543    time elapsed: 64.10 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 22784/37543    time elapsed: 69.85 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 24873/37543    time elapsed: 75.17 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 25712/37543    time elapsed: 77.19 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 27135/37543    time elapsed: 80.61 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 28391/37543    time elapsed: 83.63 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 29912/37543    time elapsed: 87.82 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 32239/37543    time elapsed: 92.62 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 32861/37543    time elapsed: 94.71 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 35151/37543    time elapsed: 101.22 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 36172/37543    time elapsed: 103.72 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 36655/37543    time elapsed: 105.09 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 37543/37543
#     time elapsed: 107.27 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 138 samples
#   * 19287 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 19287/19287
#     ** dropping 17 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 2032/19270    time elapsed: 3.83 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 3380/19270    time elapsed: 6.84 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 4518/19270    time elapsed: 9.62 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 5216/19270    time elapsed: 11.70 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 6104/19270    time elapsed: 13.25 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 7302/19270    time elapsed: 14.64 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 8207/19270    time elapsed: 16.87 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 8939/19270    time elapsed: 18.96 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 9659/19270    time elapsed: 20.91 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 10475/19270    time elapsed: 23.24 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 11497/19270    time elapsed: 25.86 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 12551/19270    time elapsed: 28.36 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 12968/19270    time elapsed: 29.49 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 13689/19270    time elapsed: 31.31 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 14346/19270    time elapsed: 32.92 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 15164/19270    time elapsed: 34.74 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 16383/19270    time elapsed: 37.35 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 16665/19270    time elapsed: 38.04 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 18072/19270    time elapsed: 41.19 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 18596/19270    time elapsed: 43.06 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 18815/19270    time elapsed: 43.69 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 19270/19270
#     time elapsed: 44.62 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 122 samples
#   * 11435 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 11435/11435
#     ** dropping 12 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1240/11423    time elapsed: 2.98 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2029/11423    time elapsed: 4.94 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2691/11423    time elapsed: 6.54 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 3092/11423    time elapsed: 7.56 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 3631/11423    time elapsed: 8.89 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 4306/11423    time elapsed: 10.11 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 4838/11423    time elapsed: 11.19 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 5237/11423    time elapsed: 12.05 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 5684/11423    time elapsed: 13.10 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 6171/11423    time elapsed: 14.38 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 6797/11423    time elapsed: 15.70 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 7437/11423    time elapsed: 17.25 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 7691/11423    time elapsed: 18.00 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 7886/11423跳过 CD4_Tcm-GPR183.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 99 samples
#   * 11479 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 11479/11479
#     ** dropping 12 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 8/11467跳过 CD4_Tem-CCR7neg.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 140 samples
#   * 16411 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 16411/16411
#     ** dropping 14 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1750/16397    time elapsed: 3.50 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2902/16397    time elapsed: 6.79 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 3855/16397    time elapsed: 9.20 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 4434/16397    time elapsed: 10.75 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 5221/16397    time elapsed: 12.82 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 6233/16397    time elapsed: 15.26 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 6998/16397    time elapsed: 17.50 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 7596/16397    time elapsed: 19.12 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 8247/16397    time elapsed: 20.58 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 8965/16397    time elapsed: 22.54 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 9831/16397    time elapsed: 24.28 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 10732/16397    time elapsed: 26.49 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 11087/16397    time elapsed: 27.68 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 11683/16397    time elapsed: 29.00 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 12233/16397    time elapsed: 30.43 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 12936/16397    time elapsed: 32.15 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 13959/16397    time elapsed: 34.67 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 14191/16397    time elapsed: 35.42 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 15404/16397    time elapsed: 38.57 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 15843/16397    time elapsed: 39.83 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 16013/16397    time elapsed: 40.32 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 16397/16397
#     time elapsed: 41.10 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 71 samples
#   * 9038 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 9038/9038
#     ** dropping 10 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 8/9028跳过 CD4_Th-TNFRSF11A.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 60 samples
#   * 8500 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 8500/8500
#     ** dropping 11 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 8/8489跳过 CD4_Th1-GZMK.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 137 samples
#   * 15591 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 15591/15591
#     ** dropping 13 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1656/15578    time elapsed: 3.83 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2743/15578    time elapsed: 6.78 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 3647/15578    time elapsed: 9.08 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 4204/15578    time elapsed: 10.47 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 4942/15578    time elapsed: 12.05 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 5896/15578    time elapsed: 14.32 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 6627/15578    time elapsed: 16.43 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 7191/15578    time elapsed: 17.85 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 7807/15578    time elapsed: 19.60 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 8495/15578    time elapsed: 21.66 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 9321/15578    time elapsed: 23.91 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 10150/15578    time elapsed: 26.15 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 10496/15578    time elapsed: 27.34 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 11043/15578    time elapsed: 28.46 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 11577/15578    time elapsed: 29.49 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 12255/15578    time elapsed: 31.10 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 13259/15578    time elapsed: 33.58 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 13490/15578    time elapsed: 34.35 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 14665/15578    time elapsed: 38.00 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 15058/15578    time elapsed: 39.20 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 15222/15578    time elapsed: 39.78 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 15578/15578
#     time elapsed: 40.69 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 18992 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 18992/18992
#     ** dropping 18 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1998/18974    time elapsed: 4.49 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 3379/18974    time elapsed: 8.60 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 4479/18974    time elapsed: 11.50 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 5124/18974    time elapsed: 13.51 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 6036/18974    time elapsed: 16.01 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 7187/18974    time elapsed: 18.30 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 8089/18974    time elapsed: 21.20 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 8790/18974    time elapsed: 23.14 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 9536/18974    time elapsed: 24.90 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 10367/18974    time elapsed: 27.15 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 11389/18974    time elapsed: 29.99 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 12394/18974    time elapsed: 32.74 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 12813/18974    time elapsed: 34.21 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 13487/18974    time elapsed: 35.70 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 14125/18974    time elapsed: 36.88 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 14944/18974    time elapsed: 39.13 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 16148/18974    time elapsed: 42.19 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 16427/18974    time elapsed: 43.05 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 17803/18974    time elapsed: 46.67 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 18311/18974    time elapsed: 48.30 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 18521/18974    time elapsed: 48.95 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 18974/18974
#     time elapsed: 50.07 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 127 samples
#   * 10144 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 10144/10144
#     ** dropping 11 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1095/10133    time elapsed: 2.92 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 1789/10133    time elapsed: 4.94 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2354/10133    time elapsed: 6.00 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 2704/10133    time elapsed: 6.73 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 3175/10133    time elapsed: 8.07 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 3782/10133    time elapsed: 9.83 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 4257/10133    time elapsed: 11.37 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 4594/10133    time elapsed: 12.34 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 4990/10133    time elapsed: 13.42 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 5419/10133    time elapsed: 15.05 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 5962/10133    time elapsed: 16.97 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 6543/10133    time elapsed: 18.49 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 6763/10133    time elapsed: 19.00 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 7125/10133    time elapsed: 19.64 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 7463/10133    time elapsed: 20.45 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 7914/10133    time elapsed: 21.57 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 8546/10133    time elapsed: 22.81 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 8682/10133    time elapsed: 24.23 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 9543/10133    time elapsed: 26.76 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 9807/10133    time elapsed: 27.78 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 9897/10133    time elapsed: 28.09 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 10133/10133
#     time elapsed: 28.67 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 139 samples
#   * 14679 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 14679/14679
#     ** dropping 14 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1563/14665    time elapsed: 3.63 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2622/14665    time elapsed: 6.54 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 3473/14665    time elapsed: 8.61 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 3981/14665    time elapsed: 9.98 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 4678/14665    time elapsed: 11.45 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 5582/14665    time elapsed: 13.08 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 6269/14665    time elapsed: 14.90 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 6800/14665    time elapsed: 16.28 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 7379/14665    time elapsed: 17.80 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 8025/14665    time elapsed: 19.50 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 8792/14665    time elapsed: 21.25 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 9588/14665    time elapsed: 23.49 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 9893/14665    time elapsed: 24.55 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 10420/14665    time elapsed: 26.17 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 10927/14665    time elapsed: 27.44 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 11564/14665    time elapsed: 28.86 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 12475/14665    time elapsed: 31.04 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 12688/14665    time elapsed: 31.74 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 13799/14665    time elapsed: 34.70 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 14183/14665    time elapsed: 35.90 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 14328/14665    time elapsed: 36.26 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 14665/14665
#     time elapsed: 37.09 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 46795 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 46795/46795
#     ** dropping 36 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 4764/46759    time elapsed: 9.96 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 8326/46759    time elapsed: 19.48 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 11097/46759    time elapsed: 26.54 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 12725/46759    time elapsed: 31.43 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 14999/46759    time elapsed: 37.10 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 17811/46759    time elapsed: 43.45 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 20046/46759    time elapsed: 49.86 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 21779/46759    time elapsed: 57.31 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 23656/46759    time elapsed: 62.20 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 25831/46759    time elapsed: 68.47 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 28350/46759    time elapsed: 73.33 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 30885/46759    time elapsed: 78.25 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 31895/46759    time elapsed: 80.42 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 33645/46759    time elapsed: 83.22 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 35271/46759    time elapsed: 85.91 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 37287/46759    time elapsed: 89.10 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 40123/46759    time elapsed: 93.56 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 40935/46759    time elapsed: 95.25 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 43746/46759    time elapsed: 100.18 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 45067/46759    time elapsed: 102.68 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 45610/46759    time elapsed: 103.76 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 46759/46759
#     time elapsed: 105.51 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 59 samples
#   * 11212 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 11212/11212
#     ** dropping 13 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 122/11199跳过 CD8_CTL-GZMK.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 34252 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 34252/34252
#     ** dropping 24 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 3543/34228    time elapsed: 5.73 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 6143/34228    time elapsed: 10.32 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 8143/34228    time elapsed: 15.75 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 9376/34228    time elapsed: 19.67 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 10965/34228    time elapsed: 24.07 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 13038/34228    time elapsed: 29.60 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 14707/34228    time elapsed: 35.14 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 15978/34228    time elapsed: 37.93 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 17285/34228    time elapsed: 40.40 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 18769/34228    time elapsed: 44.09 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 20630/34228    time elapsed: 48.00 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 22539/34228    time elapsed: 51.86 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 23281/34228    time elapsed: 53.81 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 24574/34228    time elapsed: 55.86 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 25698/34228    time elapsed: 58.23 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 27146/34228    time elapsed: 61.00 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 29309/34228    time elapsed: 64.77 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 29836/34228    time elapsed: 66.60 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 32029/34228    time elapsed: 70.72 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 34228/34228
#     time elapsed: 74.56 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 31588 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 31588/31588
#     ** dropping 25 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 3261/31563    time elapsed: 3.07 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 5563/31563    time elapsed: 5.92 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 7389/31563    time elapsed: 8.04 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 8492/31563    time elapsed: 9.62 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 9979/31563    time elapsed: 21.08 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 11912/31563    time elapsed: 54.21 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 13379/31563    time elapsed: 57.62 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 14545/31563    time elapsed: 59.10 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 15763/31563    time elapsed: 62.18 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 17155/31563    time elapsed: 64.36 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 18892/31563    time elapsed: 66.80 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 20635/31563    time elapsed: 69.03 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 21313/31563    time elapsed: 70.10 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 22489/31563    time elapsed: 71.61 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 23546/31563    time elapsed: 72.96 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 24930/31563    time elapsed: 74.77 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 26948/31563    time elapsed: 77.11 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 27442/31563    time elapsed: 77.93 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 29538/31563    time elapsed: 80.75 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 30417/31563    time elapsed: 81.96 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 30787/31563    time elapsed: 82.51 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 31563/31563
#     time elapsed: 83.38 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 32614 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 32614/32614
#     ** dropping 28 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 3395/32586    time elapsed: 3.81 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 5805/32586    time elapsed: 6.73 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 7724/32586    time elapsed: 8.96 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 8864/32586    time elapsed: 10.65 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 10414/32586    time elapsed: 12.83 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 12383/32586    time elapsed: 15.52 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 13904/32586    time elapsed: 17.94 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 15077/32586    time elapsed: 19.65 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 16333/32586    time elapsed: 21.62 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 17782/32586    time elapsed: 23.98 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 19545/32586    time elapsed: 26.57 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 21352/32586    time elapsed: 29.20 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 22032/32586    time elapsed: 30.40 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 23263/32586    time elapsed: 32.33 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 24372/32586    time elapsed: 33.92 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 25795/32586    time elapsed: 36.22 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 27849/32586    time elapsed: 39.01 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 28385/32586    time elapsed: 40.08 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 30509/32586    time elapsed: 43.43 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 31436/32586    time elapsed: 44.95 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 31799/32586    time elapsed: 45.65 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 32586/32586
#     time elapsed: 46.81 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 37644 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 37644/37644
#     ** dropping 25 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 3704/37619    time elapsed: 5.06 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 6595/37619    time elapsed: 9.35 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 9032/37619    time elapsed: 12.83 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 10508/37619    time elapsed: 15.37 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 12308/37619    time elapsed: 18.09 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 14521/37619    time elapsed: 21.33 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 16363/37619    time elapsed: 24.18 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 17863/37619    time elapsed: 26.55 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 19386/37619    time elapsed: 28.96 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 21144/37619    time elapsed: 31.99 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 23246/37619    time elapsed: 35.35 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 25333/37619    time elapsed: 38.46 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 26093/37619    time elapsed: 39.82 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 27351/37619    time elapsed: 41.73 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 28655/37619    time elapsed: 43.63 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 30162/37619    time elapsed: 45.91 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 32390/37619    time elapsed: 48.80 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 33072/37619    time elapsed: 50.15 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 35297/37619    time elapsed: 54.89 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 36300/37619    time elapsed: 56.77 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 36757/37619    time elapsed: 57.70 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 37619/37619
#     time elapsed: 59.11 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 103280 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 103280/103280
#     ** dropping 53 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 10063/103227    time elapsed: 16.11 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 18478/103227    time elapsed: 31.05 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 25445/103227    time elapsed: 42.88 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 29802/103227    time elapsed: 51.25 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 35355/103227    time elapsed: 61.22 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 41366/103227    time elapsed: 71.48 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 46527/103227    time elapsed: 80.96 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 51073/103227    time elapsed: 89.10 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 55262/103227    time elapsed: 97.23 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 60208/103227    time elapsed: 106.61 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 65789/103227    time elapsed: 116.73 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 71491/103227    time elapsed: 127.18 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 73786/103227    time elapsed: 131.94 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 77118/103227    time elapsed: 137.67 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 80839/103227    time elapsed: 144.10 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 84636/103227    time elapsed: 151.07 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 90110/103227    time elapsed: 159.61 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 92145/103227    time elapsed: 164.08 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 96857/103227    time elapsed: 172.98 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 99721/103227    time elapsed: 178.20 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 101051/103227    time elapsed: 181.09 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 103227/103227
#     time elapsed: 184.81 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 119 samples
#   * 13460 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 13460/13460
#     ** dropping 14 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 146/13446跳过 gdT2-GZMH.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 141 samples
#   * 23208 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 23208/23208
#     ** dropping 21 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 2401/23187    time elapsed: 3.72 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 4077/23187    time elapsed: 6.54 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 5391/23187    time elapsed: 8.73 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 6187/23187    time elapsed: 10.29 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 7261/23187    time elapsed: 12.07 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 8690/23187    time elapsed: 14.45 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 9743/23187    time elapsed: 16.52 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 10587/23187    time elapsed: 17.96 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 11500/23187    time elapsed: 19.58 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 12541/23187    time elapsed: 21.54 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 13808/23187    time elapsed: 23.77 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 15095/23187    time elapsed: 25.98 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 15558/23187    time elapsed: 26.91 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 16413/23187    time elapsed: 28.47 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 17207/23187    time elapsed: 29.83 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 18202/23187    time elapsed: 31.61 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 19720/23187    time elapsed: 34.02 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 20074/23187    time elapsed: 34.75 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 21749/23187    time elapsed: 37.84 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 22376/23187    time elapsed: 38.99 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 22638/23187    time elapsed: 39.54 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 23187/23187
#     time elapsed: 40.45 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 34081 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 34081/34081
#     ** dropping 27 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 3420/34054    time elapsed: 5.26 min
# ...
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 46575 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 46575/46575
#     ** dropping 35 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 4704/46540    time elapsed: 7.59 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 8222/46540    time elapsed: 13.75 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 10999/46540    time elapsed: 18.38 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 12609/46540    time elapsed: 21.68 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 14844/46540    time elapsed: 25.59 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 17573/46540    time elapsed: 30.92 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 19832/46540    time elapsed: 35.23 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 21566/46540    time elapsed: 38.34 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 23451/46540    time elapsed: 41.76 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 25632/46540    time elapsed: 45.81 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 28190/46540    time elapsed: 50.08 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 30693/46540    time elapsed: 53.77 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 31674/46540    time elapsed: 55.48 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 33419/46540    time elapsed: 57.91 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 35054/46540    time elapsed: 60.00 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 37054/46540    time elapsed: 62.85 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 39906/46540    time elapsed: 66.39 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 40719/46540    time elapsed: 67.89 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 43530/46540    time elapsed: 72.02 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 44883/46540    time elapsed: 74.00 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 45408/46540    time elapsed: 74.88 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 46540/46540
#     time elapsed: 76.25 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 137 samples
#   * 17212 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 17212/17212
#     ** dropping 15 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1798/17197    time elapsed: 2.20 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 3043/17197    time elapsed: 4.00 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 4024/17197    time elapsed: 5.19 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 4630/17197    time elapsed: 6.17 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 5439/17197    time elapsed: 7.20 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 6426/17197    time elapsed: 8.40 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 7235/17197    time elapsed: 9.50 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 7892/17197    time elapsed: 10.38 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 8555/17197    time elapsed: 11.28 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 9289/17197    time elapsed: 12.30 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 10176/17197    time elapsed: 13.51 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 11107/17197    time elapsed: 14.75 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 11458/17197    time elapsed: 15.30 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 12065/17197    time elapsed: 16.12 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 12657/17197    time elapsed: 16.90 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 13428/17197    time elapsed: 17.91 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 14538/17197    time elapsed: 19.20 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 14810/17197    time elapsed: 19.68 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 16145/17197    time elapsed: 21.71 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 16600/17197    time elapsed: 22.40 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 16777/17197    time elapsed: 22.69 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 17197/17197
#     time elapsed: 23.25 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 87 samples
#   * 14525 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 14525/14525
#     ** dropping 9 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 82/14516跳过 pDC-LILRA4.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 67 samples
#   * 12294 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 12294/12294
#     ** dropping 10 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1278/12284    time elapsed: 1.39 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2181/12284    time elapsed: 2.63 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 2910/12284跳过 Plasma_B-IGHA1.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 134 samples
#   * 17139 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 17139/17139
#     ** dropping 17 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1704/17122    time elapsed: 2.04 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2942/17122    time elapsed: 3.70 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 3951/17122    time elapsed: 4.96 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 4566/17122    time elapsed: 5.92 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 5377/17122    time elapsed: 7.02 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 6421/17122    time elapsed: 8.31 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 7234/17122    time elapsed: 9.50 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 7876/17122    time elapsed: 10.34 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 8574/17122    time elapsed: 11.34 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 9302/17122    time elapsed: 12.41 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 10238/17122    time elapsed: 13.66 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 11183/17122    time elapsed: 15.01 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 11511/17122    time elapsed: 15.56 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 12106/17122    time elapsed: 16.39 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 12696/17122    time elapsed: 17.15 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 13456/17122    time elapsed: 18.17 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 14495/17122    time elapsed: 19.41 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 14736/17122    time elapsed: 19.94 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 16041/17122    time elapsed: 21.84 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 16518/17122    time elapsed: 22.51 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 16678/17122    time elapsed: 22.78 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 17122/17122
#     time elapsed: 23.27 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 127 samples
#   * 13049 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 13049/13049
#     ** dropping 13 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 1356/13036    time elapsed: 1.52 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 2322/13036    time elapsed: 2.71 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 3107/13036    time elapsed: 3.68 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 3561/13036    time elapsed: 4.32 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 4177/13036    time elapsed: 5.09 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 4968/13036    time elapsed: 5.98 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 5583/13036    time elapsed: 6.81 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 6084/13036    time elapsed: 7.55 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 6602/13036    time elapsed: 8.35 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 7126/13036    time elapsed: 9.05 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 7831/13036    time elapsed: 9.91 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 8544/13036    time elapsed: 10.82 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 8788/13036    time elapsed: 11.19 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 9237/13036    time elapsed: 11.80 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 9696/13036    time elapsed: 12.36 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 10264/13036    time elapsed: 13.08 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 11033/13036    time elapsed: 13.96 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 11211/13036    time elapsed: 14.30 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 12250/13036    time elapsed: 15.72 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 12604/13036    time elapsed: 16.24 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 12711/13036    time elapsed: 16.42 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 13036/13036
#     time elapsed: 16.80 min
#     * writing output
# done.
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 47 samples
#   * 7829 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 7829/7829
#     ** dropping 8 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 50/7821跳过 Switched_Memory_B-IGHE.bed，错误信息: list index out of range
# cis-QTL mapping: nominal associations for all variant-phenotype pairs
#   * 142 samples
#   * 29393 phenotypes
#   * 19 covariates
#   * 7540937 variants
#   * including 1 interaction term(s)
#     * using 0.1 MAF threshold
#   * cis-window: ±1,000,000
#   * checking phenotypes: 29393/29393
#     ** dropping 25 phenotypes without variants in cis-window
#   * Computing associations
#     Mapping chromosome chr1
#     processing phenotype 2894/29368    time elapsed: 3.22 min
#     * writing output
#     Mapping chromosome chr2
#     processing phenotype 5100/29368    time elapsed: 6.02 min
#     * writing output
#     Mapping chromosome chr3
#     processing phenotype 6910/29368    time elapsed: 8.35 min
#     * writing output
#     Mapping chromosome chr4
#     processing phenotype 7973/29368    time elapsed: 9.89 min
#     * writing output
#     Mapping chromosome chr5
#     processing phenotype 9329/29368    time elapsed: 11.58 min
#     * writing output
#     Mapping chromosome chr6
#     processing phenotype 11112/29368    time elapsed: 13.73 min
#     * writing output
#     Mapping chromosome chr7
#     processing phenotype 12567/29368    time elapsed: 15.74 min
#     * writing output
#     Mapping chromosome chr8
#     processing phenotype 13766/29368    time elapsed: 17.29 min
#     * writing output
#     Mapping chromosome chr9
#     processing phenotype 14962/29368    time elapsed: 18.90 min
#     * writing output
#     Mapping chromosome chr10
#     processing phenotype 16247/29368    time elapsed: 20.66 min
#     * writing output
#     Mapping chromosome chr11
#     processing phenotype 17780/29368    time elapsed: 22.53 min
#     * writing output
#     Mapping chromosome chr12
#     processing phenotype 19382/29368    time elapsed: 24.55 min
#     * writing output
#     Mapping chromosome chr13
#     processing phenotype 19964/29368    time elapsed: 25.46 min
#     * writing output
#     Mapping chromosome chr14
#     processing phenotype 20990/29368    time elapsed: 26.70 min
#     * writing output
#     Mapping chromosome chr15
#     processing phenotype 22013/29368    time elapsed: 27.92 min
#     * writing output
#     Mapping chromosome chr16
#     processing phenotype 23336/29368    time elapsed: 29.64 min
#     * writing output
#     Mapping chromosome chr17
#     processing phenotype 25092/29368    time elapsed: 31.66 min
#     * writing output
#     Mapping chromosome chr18
#     processing phenotype 25579/29368    time elapsed: 32.43 min
#     * writing output
#     Mapping chromosome chr19
#     processing phenotype 27537/29368    time elapsed: 35.11 min
#     * writing output
#     Mapping chromosome chr20
#     processing phenotype 28315/29368    time elapsed: 36.23 min
#     * writing output
#     Mapping chromosome chr21
#     processing phenotype 28637/29368    time elapsed: 36.75 min
#     * writing output
#     Mapping chromosome chr22
#     processing phenotype 29368/29368
#     time elapsed: 37.64 min
#     * writing output
# done.
